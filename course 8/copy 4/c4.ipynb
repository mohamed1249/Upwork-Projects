# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# # Ahmad Abdulla
#
# ## Problem 1:
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# $$ℎ_𝑓 = 𝑓. \frac {L. U^2} {2.𝑑𝑔}$$
#
# where 𝑓 is a dimensionless loss factor (obtain with Haaland equation or Moody chart, using
#
# $$\frac ∈ D = 0.001$$
#
# ![image.png](attachment:image.png)
#
# ### Question to be Answered
#
# Assuming negligibly small minor losses (entry and exit and elbows) and the pump operates with an efficiency of 86 %, what is the required input power to run the pump?

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Answer 1
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ![image-2.png](attachment:image-2.png)
# 1. Water density at $20$ degree centigrade (shown in figure 1) = ρ = 998.2 $\frac {kg} {m^3}$
#
# 2. Water dynamic viscosity at $20$ degree centigrade (shown in figure 1) = µ = 0.0010020 $\frac {kg} {m.s}$.
#
# 3. Pipe Internal Diameter = d = 0.8 m
#
# 4. Fluid velocity = v
#
# Flow rate General Equation
#
# $$Q = A * v  - - - - (1)$$
#
# Rearrange equation
# $$v = \frac Q A  - - - - (2)$$
#
# Put A in eq (2)
# $$v = \frac Q {\frac {\pi} 4 d^2}  - - - - (3)$$
#
# eq (3)
# $$v = \frac {4 \frac {m^3} {S}} {\frac {3.14} 4 {0.8}^2}  - - - - (3)$$
#
# $$v = 7.96 m^3$$
#
# $$Re = \frac {ρvd} {\mu} - - - - (4)$$
#
# put values in eq (4)
#
# $$Re = \frac {(998.29 kg/m^3)( 7.96 m^2/s(0.8 𝑚)} {(0.001002 kg/m.s)}$$
#
# Solve
#
# $$Re = 6344421.876$$
#
# $$Re = 6.344 x 10^6$$
#
# $$\frac ∈ D = 0.001 = 1x10^{-3}$$
#
# From Moody Chart
# $$𝑓 ≈ 0.01972 $$

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
#
# ### Bernoulli's Principle for Calcultaion of Headless
#
# $$\frac {P_1} γ \frac {v_1^2} {2g} γ + z_1 + h_p = \frac {P_2} γ \frac {v_2^2} {2g} γ + z_2 + h_f$$
#
# put values in expression above, put v and p equals to ZER0;
# $$0+0+z_1+h_p = 0+0+z_2+h_f$$
#
# $$h_p = z_2 - z_1 + h_f - - - - (5)$$
# put value of $h_f$ in eq (5)
#
# $$h_p = z_2 - z_1 + f. \frac {z_2 . v^2} {2.d.g}$$
#
# $$h_p = z_2 - z_1 + 0.01972. \frac {(7.96^2) m/s . 45 m} {2(0.8 m)(9.8 m/s^2)}$$
#
# Simplify
# $$h_p = z_2 - z_1 + 3.586 m$$
#
# Given; $z_1 = 0$ and $z_2 = 45$
#
# $$h_p = 45 - 0 + 3.586 = 48.586 m$$
#
#
#
# ### Power Principle Equation
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# $$P_{in} = \frac {ρgh_pQ} η$$
# put values
#
# $$P_{in} = \frac {(998.29kg/m3)(9.81m/s2)(48.586m)(4.0m/s3)} {0.86} = 2213086.628 Watt$$
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# **Power required for running pump is ≈ 2213.0866 Kilo Watt (KW)**

# %% [markdown]
# ## problem 2
#
# Vapor in a multi-effect distillation plant such as the one shown in Figure 2 vapor can carry mist droplets with salt and other contaminants. To limit the amount of contaminants that reach the vapor exit (see arrow in the figure), we may want to control the speed of the vapor so that it can carry only the liquid droplets smaller than a certain size upwards.
#
# Question: If we have a vertical ow of saturated water vapor at 0.15 bar absolute pressure and we want to allow it to carry droplets with a maximum diameter of 120𝜇𝜇m, what is the maximum velocity at which the vapor can flow to not carry larger droplets?)
#
# ![image.png](attachment:image.png)
# <center>Figure 2</center>
#
# #### Assumptions and hints:
#
# - Assume steam is saturated. Definition: Water heated to boiling point is vaporized and turns to saturated steam. If saturated steam is heated further (temperature above boiling point at given pressure), dry steam is generated and traces of moisture are gone (and in such case we have superheated steam).
# - Assume droplet is spherical and can be treated as a rigid sphere a first approximation.
# - Use the density and viscosity of liquid and vapor water at the appropriate saturation temperature. One reference for such properties can be found here: NIST - Thermophysical Properties of Fluid Systems.
# - Hint: start with a force balance. Assume that droplet would need to travel vertically upward (towards the screen above).

# %% [markdown]
# ## Answer 2
#
# Coefficient of drag for rigid sphere;
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# $$C_d = \frac {24} {Re} + 2.6 \frac {Re/5} {1 + {(Re/5})^{1.52}} + 0.411 \frac {{(Re/263000)}^{-7.94}} {1+(Re/263000)^{-8}} + 0.25 \frac {Re x 10^{-6}} {1 + Re x 10^{-6}} - - - - (2a)$$
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# Available Values
#
# $𝜌_𝐿 = 986.15 𝐾𝑔/𝑚3$
#
# $𝜌_𝑉 = 0.099799𝐾𝑔/𝑚3$
#
# $𝜇_𝐿 = 0.00051198 𝑃𝑎.s$
#
# $𝜇_𝑉 = 1.065 × 10−5 𝑃𝑎.s$
#
# $D = 120 𝜇𝑚$
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# #### The Maximum velocity at which the vapor can flow to not carry larger droplets (𝑈_𝑣 =? )
#
# ### Force Balance Formula
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">
# $$F_{Gravity} = F_{Buoyancy} + F_{Drag}$$
#
# $$𝜌_{(liquid)} \mu (\frac{d^3} {6}) g = 𝜌_{(vapor)} \mu (\frac{d^3} {6}) + \frac 1 2 𝜌_{(liquid)} \mu (\frac{d^3} {4}) C_d (V_{vapor})^2 $$
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# Rearrange equation
#
# $$C_d{(V_{vapor})^2} = \frac {4dg(𝜌_{liquid} - 𝜌_{vapor})} {3𝜌_{vapor}}$$
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Important Python Libraries Used
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sci
from utils import *
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
vaue_of_gravity= 9.81                
rho_w = 986.15           
rho_v = 0.099799      
mio_w = 0.00051198  
mio_v = 0.00001065

def CeeDee(dk ,rho = rho_v, v = 1, mio = mio_v):
    Re = rho*v*dk/mio
    Cd = 24/Re + 2.6*(Re/5)/(1 + (Re/5)**1.52) + 0.411*(Re/263000)**(-7.94)/(1+ (Re/263000)**(-8)) + 0.25*(Re*10**-6)/(1+ Re*10**-6)
    return Cd
    
α =  rho_w* vaue_of_gravity*4/( rho_v*3)
def F_function(Dk):
    return CeeDee(Dk)/α

d = np.zeros(100)
d[0] = 0.00015
for i in range(1,100):
    d[i] = F_function(d[i-1])*0.5 + d[i-1]*0.5

plt.figure(figsize=(15, 6))
plt.plot(range(100), d )
plt.show()

# %%
print(f"The Largest Droplet Size is {d[-1]}")
# Out:
# The Largest Droplet Size is 0.00014395697657224184

# %% [markdown]
# ## Problem 3
#
# To have a robust yet economical mass flow rate measurement with a relatively low pressure loss, a venturi flow meter may be utilized. Let us consider the performance and likelihood of cavitation in a horizontal venturi. We shall assume constant fluid properties, and denote the contraction ratio as β, defined as β = dthroat=dpipe. For a venturi, the mass flowrate can be determined as a function of fluid density, measured differential pressure ∆p = ppipe − pthroat and contraction ratio β.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (A) Sketch the venturi and label locations where you define pressures and velocities in the equations.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (B) As no instrument is perfect, from the lectures we recall that above equation needs to be multiplied by a discharge coefficient. Assume it has a constant value of Cd = 0.965. Our venturi has β = 0:6 and Athroat = 0:003 m2. We shall assume that the uncertainty in density is 2 %, in area of throat 1 % and in β is 1 % for each, all with 95 % confidence. If mass flow rate of 25 kg/s is to be determined within 5 % with 95 % confidence, what is maximum uncertainty allowable for the differential pressure measurement?

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ### (a) Gauss method Here
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
Cd_value = 0.965 
rho_value = 998.29
A_value = 0.004
beta_value = 0.5
mass_flow_rate_value = 20
rho_tilde_value = 0.04*rho_value
A_tilde_value = 0.01*A_value 
beta_tilde_value = 0.03*beta_value
mass_flow_rate_tilde_value = 0.05*mass_flow_rate_value

# %%
Cd_value, rho_value, A_value, beta_value, mass_flow_rate_value
# Out:
# (0.965, 998.29, 0.004, 0.5, 20)

# %%
rho_tilde_value, A_tilde_value, beta_tilde_value, mass_flow_rate_tilde_value, b4_value
# Out:
# (39.931599999999996, 4e-05, 0.015, 1.0, 0.0625)

# %%
dp_value = ((mass_flow_rate_tilde_value / Cd_value / A_value) **2) * (1-b4_value) / rho_value / 2
dp_tilde_value = dp_value*np.sqrt((2*mass_flow_rate_tilde_value / mass_flow_rate_value )**2 + \
                                  (-2*A_tilde_value / A_value )**2 + \
                      (-1 * rho_tilde_value / rho_value)**2 + ((-4 * b4_value / (1-b4_value))*\
                                                               beta_tilde_value / beta_value)**2)

# %%
# %%render
# dp_value = ((mass_flow_rate_tilde_value / Cd_value / A_value )**2) * (1-b4_value) / rho_value / 2
# Out:
# UsageError: Cell magic `%%render` not found.

# %%
dp_value, dp_tilde_value
# Out:
# (31.514465859468633, 3.4614304905095894)

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ### (b) Monte Carlo method
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
import numpy
iterations_value = 1000000
dp_samp_value = numpy.empty(iterations_value)
print("Simulation Started")
for i in range(iterations_value):
        M = np.random.normal(loc=mass_flow_rate_value,
                                 scale=mass_flow_rate_tilde_value,
                                 size=iterations_value)

        R = np.random.normal(loc=rho_value,
                                 scale=rho_tilde_value,
                                 size=iterations_value)

        A = np.random.normal(loc= A_value,
                                 scale=A_tilde_value,
                                 size=iterations_value)

        B = np.random.normal(loc=beta_value,
                                 scale=beta_tilde_value,
                                 size=iterations_value)

        dp_samp_value[i] = finalF(M, R, A, B)
print("Simulation End")
# Out:
# Simulation Started
# Simulation End

# %%
np.mean(dp_samp_value)
# Out:
# 12613.091425432878

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sci

plt.figure()
plt.hist(dp_samp_value, bins = 50, color='red')
plt.title(f'Monte Carlo Simulation Average = {np.mean(dp_samp_value):.2f}, std = {np.std(dp_samp_value)*2:.2f}')

# %% [markdown]
# (C) If cavitation inception is expected at σ=(ρ_ref-ρ_vapor)/(1/2 ρU_ref^2 )≤1.8, with cavitation number deﬁned based on ’reference’ pressure and velocity upstream of the throat. For the above ﬂow rate, what is minimum pressure allowed at the venturi inlet to likely avoid cavitation? Assume water temperature is 20 ◦C.
#
# Hint: start by deﬁning the cavitation number and be consistent with labeling from part A.
#
# σ=(P-P_vapor)/(1/2 ρU_ref^2 )≤1.8
# 	σ  (P_pipe-P_vapor)/(1/2 ρv_pipe^2 )=1.8
# Know solve for v_throat:
# 	v_throat=m ̇/(ρA_throat )
# 	v_throat=25/(998.29)(0.003)
# 	v_throat=8.34 m/s
#
# Know solve for v_pipe:
# ∴ β^2=0.6  from the quastoin
# 	v_pipe=v_throat  β^2
# 	v_pipe=(8.34) (0.6)^2
# 	v_pipe=3.0m/s

# %% [markdown]
# ## Problem 4
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ### define constants
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
rho_value = 1025
mu_value = 0.00109
mass_flow_rate_value = 750
d_before_value = 0.6
eps_before_value = 4.5*1e-3
gravity_value = 9.81
L_value = 400
eta_value = 0.82
rate_before_value = 0.15

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## define Cost Function
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
def cost(d_before,eps_before,rate_before):
    q = mass_flow_rate_value / rho_value
    q2 = (np.pi*d_before**2/4)
    v = q / q2
    temp = rho_value * v * d_before_value
    Re = temp / mu_value
    log_val = np.log10((eps_before/d_before/3.7)**(1.11)+(6.9/Re))
    f = (-1.8 * log_val)**(-2)
    ans = ((v**2)/(2*gravity_value))
    h = f * (L_value / d_before) * ans
    rho_g = rho_value * gravity_value
    rho_g_q = rho_g * q
    rho_g_q_h = rho_g_q * h
    rho_g_q_h_eta = rho_g_q_h / eta_value
    P = rho_g_q_h_eta/1000
    res = P * (24 * 365) * rate_before
    return res

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## (A) What is the electricity cost per year for this single pipeline?
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
cost_before1 = int(round(cost(d_before_value,eps_before_value,rate_before_value)))
print("Eletricity Cost per Year are {0} dollars".format(cost_before1))
# Out:
# Eletricity Cost per Year are 92786 dollars

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ##  (B)  How many months(approximately) after the installation will the cost be recovered?
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
def compute(eps,d):

    q = mass_flow_rate_value / rho_value
    v = q / (np.pi*d**2/4)
    Re = rho_value*v*d/mu_value
    f = (-1.8*np.log10((eps/d/3.7)**(1.11)+(6.9/Re)))**(-2)
    h = f*L_value*(v**2)/d/2/gravity_value
    p = (rho_value*gravity_value*q*h/eta_value)/1000
    
    return p

# %%
Pn = compute(eps_before_value,d_before_value)
Pw = compute(0.2e-3,d_before_value-10e-3)

Pn, Pw
# Out:
# (70.61353939958342, 35.007400773619416)

# %%
I = 300*400
a = 8760*0.10/2
b = 2.5*8760

# %%
print (f"Highet the raised electricity price = {(I-a*(Pn-Pw))/(b*(Pn-Pw))}$")
# Out:
# Highet the raised electricity price = 0.1338906566745461$

# %% [markdown]
# ## Problem 5
#
# All other things being equal, smoother pipe, larger diameter, more gradual pipe transitions etc. will lead to a reduced pressure drop in pipe network. And, ideally none of the components should be inﬂicted by cavitation. During the course we discussed pressure loss estimation based of textbook approaches, and calculations nowadays typically handled by commercial codes. For this assignment, you will examine a simple pipe network and study eﬀect of uncertainty to network performance using the Monte-Carlo method for uncertainty propagation.
#
# Use a textbook approach (with friction factors e.g. from Moody diagram (Figure 6.13 in White) based on given roughness White (1998)) to simulate the performance the network should have. Note that simulated performance may deviate from measured performance not only due to uncertainty about initial dimensions of components, but also due to installation deviating from design (e.g. extra bends and rough welds), eﬀects of corrosion and fouling on roughness given age of pipeline, etc.
#
# For a complex pipe network, commercial or freeware codes would typically be used to evaluate performance of the network. While the solution methodologies vary, the basic conservation laws remain unchanged. Hence, let us consider a simple example pipe network and a) write our own code to solve for the ﬂow rates, b) use WNTR simulation library in python to resolve the same network and ensure your answers match, and c) implement a Monte-Carlo solution.
#
# Assume pipe diameters have uniform distribution between 98% and 103% of nominal diameter and roughness has an exponential probability distribution with mean being the listed value. Rerun the Monte Carlo simulation with water properties at 10◦C and 30◦C (in addition to the original design point of 20◦C) in order to evaluate the inﬂuence of temperature on system performance. NOTE: The WNTR simulation library in python will be used for comparison in
#
# ![image.png](attachment:image.png)
# Figure 3: Pipe network to analyze. Figure adapted and modifed from Jeppson (1974), and the
# values have been changed.
#
#
# a) Use whichever method you are most comfortable with (Linearized approach from lectures, Hardy-Cross, Newton-Rhapson, or other) to setup equations and then solve the ﬂow rates and pressures throughout the network. Start from conservation of mass and consider only the major losses for ∆p calculations(i.e. neglect minor losses due to ﬁttings and instruments).
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Data Loading
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
pipes, loopsind, param, Qsd, numnodes, numpipes = load_networkB()
print("Loaded")
pipes.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# Loaded
# C:\Users\LAPTOP WORLD\AppData\Local\Temp\ipykernel_12964\2154991733.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   pipes.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_588c7_row0_col0, #T_588c7_row0_col1, #T_588c7_row0_col2, #T_588c7_row3_col1, #T_588c7_row4_col7, #T_588c7_row5_col5, #T_588c7_row5_col6, #T_588c7_row5_col7, #T_588c7_row8_col3, #T_588c7_row8_col7, #T_588c7_row9_col7, #T_588c7_row10_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_588c7_row0_col3, #T_588c7_row0_col4, #T_588c7_row1_col4, #T_588c7_row2_col3, #T_588c7_row2_col4, #T_588c7_row3_col4, #T_588c7_row4_col3, #T_588c7_row4_col4, #T_588c7_row5_col3, #T_588c7_row5_col4, #T_588c7_row6_col4, #T_588c7_row7_col2, #T_588c7_row7_col4, #T_588c7_row7_col7, #T_588c7_row8_col1, #T_588c7_row8_col4, #T_588c7_row9_col3, #T_588c7_row10_col5, #T_588c7_row10_col6, #T_588c7_row11_col0, #T_588c7_row11_col4 {
# ...

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Define Flow
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
numloops = loopsind.shape[1]

# %%
Aflow_value = np.zeros((numnodes - 1, numpipes))
bflow_value = np.zeros(numnodes - 1)
qold_value = np.ones(numpipes)
for i in range(numnodes - 1):
    nodeid = i+1
    Aflow_value[i, pipes['start']==i], Aflow_value[i, pipes['end']==i] = -1, 1
    bflow_value[i] = -Qsd[i]

# %%
bhead = np.zeros(numloops)
b = np.hstack((bflow_value, bhead))
b
# Out:
# array([-0.4 , -0.  ,  0.6 ,  0.2 , -0.32,  0.12, -0.8 ,  0.  ,  0.  ,
#         0.  ,  0.  ,  0.  ])

# %%
max_iter = 20
storeQ = np.empty((numpipes, max_iter))
error = np.empty((numpipes, max_iter))
pd.DataFrame(data=error).style.background_gradient(cmap='coolwarm').set_precision(15)
# Out:
# C:\Users\LAPTOP WORLD\AppData\Local\Temp\ipykernel_12964\3653129350.py:4: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   pd.DataFrame(data=error).style.background_gradient(cmap='coolwarm').set_precision(15)
# <style type="text/css">
# ...

# %%
for ii in range(max_iter):  
    f_value = fhalland(qold_value, pipes, param)
    beta_value = f_value * abs(qold_value) * pipes['k']
    Aloop_value = loopsind.T @ np.diag(beta_value)
    A_value = np.vstack((Aflow_value, Aloop_value))
    z_value = np.linalg.solve(A_value, b)
    qnew = 0.5 *z_value + (1-0.5)*qold_value
    error[:,ii], storeQ[:,ii] = abs(qnew - qold_value), qnew
    qold_value = qnew
qold_value
# Out:
# array([ 0.11995114,  0.25284248,  0.22127304,  0.28005038, -0.13289038,
#         0.21343356,  0.25931945,  0.42701794, -0.17298148,  0.03366478,
#         0.1595506 ,  0.14122342])

# %%
pipes['Q'] = qnew
pipes['hl'] = beta_value * qnew
pipes.T
# Out:
#                0            1           2            3           4   \
# id       1.000000     2.000000    3.000000     4.000000    5.000000
# start    0.000000     1.000000    3.000000     0.000000    1.000000
# end      1.000000     2.000000    2.000000     3.000000    4.000000
# D        0.600000     0.450000    0.600000     0.450000    0.600000
# eps      0.000400     0.000400    0.000400     0.000400    0.000400
# L      580.000000   600.000000  600.000000   430.000000  450.000000
# k      616.301147  2686.642717  637.552910  1925.427281  478.164683
# Q0       0.200000     0.200000    0.200000     0.200000    0.000000
# Q        0.119951     0.252842    0.221273     0.280050   -0.132890
# hl       0.169935     3.353700    0.580798     2.942837   -0.160858
#
#                5            6            7            8           9   \
# id       6.000000     7.000000     8.000000     9.000000   10.000000
# start    6.000000     4.000000     6.000000     7.000000    2.000000
# ...

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Plots
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
plt.figure(figsize=(14,6))
plt.subplot(211)
plt.plot(range(max_iter), storeQ.T)
plt.title('13 Nodes Floats')
plt.subplot(212)
plt.plot(range(max_iter), error.T)
plt.title('Errors Values (approach zero)')
plt.show()

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ### Part B of Problem 5
#
# b) Assuming node [1] is at 200 kPa (gauge) and that water to supply nodes ([1], [5] and [7]) was delivered from open reservoirs at 0 kPa (gauge) by pumps that are 85% eﬃcient, how much energy (in kWh) per day is required to deliver the water (report for each pump)?
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
Q = pipes['Q']
hl = pipes['hl']
P = np.zeros(8)
P[0] = 200000 / (param['rho'] * param['g'])

# %%
P[1] = P[0] - np.sign(Q[1]) * hl[0]
P[1]
# Out:
# 20.21742494387658

# %%
P[2] = P[1] - np.sign(Q[2]) * hl[1]
P[2]
# Out:
# 16.863724972988322

# %%
P[3] = P[1] - np.sign(Q[3]) * hl[3]
P[3]
# Out:
# 17.27458842849384

# %%
P[4] = P[3] + np.sign(Q[4]) * hl[5]
P[4]
# Out:
# 16.940903070315365

# %%
P[5] = P[4] - np.sign(Q[5]) * hl[8]
P[5]
# Out:
# 19.40565741847789

# %%
P[7] = P[6] - np.sign(Q[7]) * hl[11]
P[7]
# Out:
# -2.9337599352678247

# %%
P[6] = P[4] - np.sign(Q[6]) * hl[9]
P[6]
# Out:
# 16.92950450574729

# %%
Q
# Out:
# 0     0.119951
# 1     0.252842
# 2     0.221273
# 3     0.280050
# 4    -0.132890
# 5     0.213434
# 6     0.259319
# 7     0.427018
# 8    -0.172981
# 9     0.033665
# 10    0.159551
# 11    0.141223
# Name: Q, dtype: float64

# %%
hl
# Out:
# 0     0.169935
# 1     3.353700
# 2     0.580798
# 3     2.942837
# 4    -0.160858
# 5     0.333685
# 6     3.525957
# 7     6.324396
# 8    -2.464754
# 9     0.011399
# 10    3.848244
# 11    2.933760
# Name: hl, dtype: float64

# %%
P
# Out:
# array([20.38735984, 20.21742494, 16.86372497, 17.27458843, 16.94090307,
#        19.40565742, 16.92950451, -2.93375994])

# %%
P_Pa_value = P * param['rho'] * param['g']
P_Pa_value
# Out:
# array([200000.        , 198332.93869943, 165433.14198502, 169463.71248352,
#        166190.25911979, 190369.49927527, 166078.43920138, -28780.18496498])

# %%
print("Power Values")
Power1 = P_Pa_value[0] * Qsd[0] / 0.85 / 1000
Power1
# Out:
# Power Values
# 94.11764705882355

# %%
Power5 = P_Pa_value[4] * Qsd[4] / 0.85 / 1000
Power5
# Out:
# 62.56574460980471

# %%
Power7 = P_Pa_value[6] * Qsd[6] / 0.85 / 1000
Power7
# Out:
# 156.30911924835854

# %%
print("Energy Values")
Energy1_value = Power1 * 24 
Energy1_value
# Out:
# Energy Values
# 2258.8235294117653

# %%
Energy5_value = Power5 * 24 
Energy5_value
# Out:
# 1501.577870635313

# %%
Energy7_value = Power7 * 24
Energy7_value
# Out:
# 3751.4188619606048

# %%
def HistoGram(All_Pressure, Pump_Power):   
    for i in range(N_junctions-1):
        plt.figure()
        plt.hist(All_Pressure[:,i], bins=100, density=True, label='MC', color='green')
        plt.title(f'Pressure at Node {i+2} MC Mean = {np.mean(All_Pressure[:,i]):.2f}, std = {np.std(All_Pressure[:,i])}')
        plt.xlabel('Pressure [m]')
        plt.ylabel('PDF')      
    
    for i in range(1):
        plt.figure()
        plt.hist(Pump_Power[:,i+1]/1000, bins=100, density=True, label='MC', color='green')
        plt.title(f'Pump Power at Node {supply_nodes[i+1]+2} MC Mean = \
        {np.mean(Pump_Power[:,i+1])/1000:.2f}, std = {np.std(Pump_Power[:,i+1])}')
        plt.xlabel('Power [KW]')
        plt.ylabel('PDF')

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Define Function for Mean. Variance, Std Deviation
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
def Variance(All_Pressure, Pump_Power):
    var_pressure = [variance(All_Pressure[:,i]) for i in range(8)]
    var_power = [variance(Pump_Power[:,i]) for i in range(2)]
    return var_pressure, var_power

# %%
def StandardDeviation(All_Pressure, Pump_Power):
    std_pressure = [np.std(All_Pressure[:,i]) for i in range(8)]
    std_power = [np.std(Pump_Power[:,i]) for i in range(2)]
    return std_pressure, std_power

# %%
def Mean(All_Pressure, Pump_Power):
    mean_pressure = [np.mean(All_Pressure[:,i]) for i in range(8)]
    mean_power = [np.mean(Pump_Power[:,i]) for i in range(2)]
    return mean_pressure, mean_power

# %%
def Plots(All_Pressure, Pump_Power, I):
    meanPressure = [np.mean(All_Pressure[:i,:]) for i in range(I)]
    meanPower = [np.mean(Pump_Power[:i,:]) for i in range(I)]
    plt.figure(figsize=(14,6))
    plt.subplot(211)
    plt.plot(range(I),meanPressure,linewidth=2)
    plt.grid()
    plt.subplot(212)
    plt.plot(range(I),meanPower,linewidth=2)
    plt.grid()

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ### Part C of Problem 5
#
# ### Load Wntr
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
import wntr

N_junctions = 8
N_pipes = 13
eta = 0.85
supply_nodes = [N_junctions-1,3]
rho = 998
g = 9.81
inp_file = "Spring 2022 Capstone.inp"

wn = wntr.network.WaterNetworkModel(inp_file)
wn

# %%
# Graph the network
wntr.graphics.plot_network(wn, title=wn.name)
# Out:
# <AxesSubplot:title={'center':'Spring 2022 Capstone.inp'}>

# %%
#Simulate hydraulics
results0 = wntr.sim.EpanetSimulator(wn).run_sim()

#Output results of interest
head_value = results0.node['head']
flowrate_value = results0.link['flowrate']
demand_value = results0.node['demand']
headloss_value = results0.link['headloss']

# %%
linktable = pd.DataFrame({'flowrate': flowrate_value.values[0,:], 'headloss':headloss_value.values[0,:]})
nodetable = pd.DataFrame({'head':head_value.values[0,:], 'demand' :demand_value.values[0,:]})
linktable.T.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b255f_row0_col0, #T_b255f_row0_col1, #T_b255f_row0_col2, #T_b255f_row0_col3, #T_b255f_row0_col5, #T_b255f_row0_col6, #T_b255f_row0_col7, #T_b255f_row0_col10, #T_b255f_row0_col11, #T_b255f_row1_col4, #T_b255f_row1_col8, #T_b255f_row1_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b255f_row0_col4, #T_b255f_row0_col8, #T_b255f_row0_col9, #T_b255f_row1_col0, #T_b255f_row1_col1, #T_b255f_row1_col2, #T_b255f_row1_col3, #T_b255f_row1_col5, #T_b255f_row1_col6, #T_b255f_row1_col7, #T_b255f_row1_col10, #T_b255f_row1_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b255f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b255f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b255f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_b255f_level0_col2" class="col_heading level0 col2" >2</th>
# ...

# %%
nodetable.T.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_aaaa5_row0_col0, #T_aaaa5_row0_col1, #T_aaaa5_row0_col2, #T_aaaa5_row0_col3, #T_aaaa5_row0_col4, #T_aaaa5_row0_col5, #T_aaaa5_row0_col6, #T_aaaa5_row0_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_aaaa5_row1_col0, #T_aaaa5_row1_col1, #T_aaaa5_row1_col2, #T_aaaa5_row1_col3, #T_aaaa5_row1_col4, #T_aaaa5_row1_col5, #T_aaaa5_row1_col6, #T_aaaa5_row1_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_aaaa5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aaaa5_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_aaaa5_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_aaaa5_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_aaaa5_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_aaaa5_level0_col4" class="col_heading level0 col4" >4</th>
# ...

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ### Part D of Problem 5
#
# d) Use WNTR and estimate the eﬀect of uncertainty in pipe conditions of pumping power needed to supply network shown in ﬁgure 3. Use your code and Monte-Carlo method for propagating uncertainty and consider
#
# i) uncertainty in pipe roughness,
# ii) uncertainty in pipe length,
# iii) uncertainty in pipe diameter (see table 1).
#
# Perform a convergence study to show that you have run enough iterations for your results to have converged. To estimate uncertainty in roughness, use a normal distribution with the mean matching the nominal roughness and the standard deviation of 1/5 the mean. Report the uncertainties in pressure throughout the system based on your MC simulation as well as the uncertainty in required pumping power at the supply node 5.
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
from statistics import variance
pascal= head_value * rho * g

# %%
pipes.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_cd988_row0_col0, #T_cd988_row0_col1, #T_cd988_row0_col2, #T_cd988_row3_col1, #T_cd988_row4_col7, #T_cd988_row5_col5, #T_cd988_row5_col6, #T_cd988_row5_col7, #T_cd988_row8_col3, #T_cd988_row8_col7, #T_cd988_row8_col8, #T_cd988_row8_col9, #T_cd988_row9_col7, #T_cd988_row10_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_cd988_row0_col3, #T_cd988_row0_col4, #T_cd988_row1_col4, #T_cd988_row2_col3, #T_cd988_row2_col4, #T_cd988_row3_col4, #T_cd988_row4_col3, #T_cd988_row4_col4, #T_cd988_row5_col3, #T_cd988_row5_col4, #T_cd988_row6_col4, #T_cd988_row7_col2, #T_cd988_row7_col4, #T_cd988_row7_col7, #T_cd988_row7_col8, #T_cd988_row7_col9, #T_cd988_row8_col1, #T_cd988_row8_col4, #T_cd988_row9_col3, #T_cd988_row10_col5, #T_cd988_row10_col6, #T_cd988_row11_col0, #T_cd988_row11_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# ...

# %%
I = 200
def MonteCarloSimulationWorking(wn, derr, lerr, do_eps, I):   
    All_Pressure = np.empty((I, N_junctions))
    Pump_Power = np.empty((I,2)) 
    d_mean = wn.query_link_attribute('diameter').to_numpy()
    l_mean = wn.query_link_attribute('length').to_numpy()
    eps_mean = wn.query_link_attribute('roughness').to_numpy()  
    for i in range(I):
        count = 0
        for pipe_name, pipe in wn.pipes():
            pipe.diameter = np.random.uniform((1-derr)*d_mean[count], (1+derr)*d_mean[count])
            pipe.length = np.random.uniform((1-lerr)*l_mean[count], (1+lerr)*l_mean[count])
            if do_eps:
                pipe.roughness = np.random.normal(eps_mean[count], eps_mean[count]/5)
            count = count + 1   
        results = wntr.sim.EpanetSimulator(wn).run_sim() 
        head = results.node['head'] # [m]
        demand = results.node['demand'] # [m^3/s]
        All_Pressure[i,:] = pd.Series.to_numpy(head.loc[0,:]) 
        demand_list = pd.Series.to_numpy(demand.loc[0,:])
        for ii in range(2):
            Pump_Power[i,ii] = All_Pressure[i, supply_nodes[ii]]*rho*g*abs(demand_list[supply_nodes[ii]])/eta      
    return(All_Pressure, Pump_Power)

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Run Monte Carlo on Network
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
wn = wntr.network.WaterNetworkModel(inp_file)
All_Pressure_values, Pump_Power_values = MonteCarloSimulationWorking(wn, 0.02, 0.01, True, I)

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Plot Means Pressure and Mean Power
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
import warnings
warnings.filterwarnings("ignore")

meanPressure = [np.mean(All_Pressure_values[:i,]) for i in range(I)]
meanPower = [np.mean(Pump_Power_values[:i,:]) for i in range(I)]
plt.figure(figsize=(14,6))
plt.subplot(211)
plt.plot(range(I), meanPressure, linewidth=1, c='red')
plt.grid()
plt.subplot(212)
plt.plot(range(I),meanPower,linewidth=1, c='green')
plt.grid()

# %%
HistoGram(All_Pressure_values, Pump_Power_values)

# %%
pressure_conv = np.empty((I,8))
for i in range(I):
    pressure_conv[i,:] = np.mean(All_Pressure_values[:i,:])
pressure_conv
# Out:
# array([[  nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan],
#        [8.097, 8.097, 8.097, 8.097, 8.097, 8.097, 8.097, 8.097],
#        [8.032, 8.032, 8.032, 8.032, 8.032, 8.032, 8.032, 8.032],
#        [8.049, 8.049, 8.049, 8.049, 8.049, 8.049, 8.049, 8.049],
#        [8.06 , 8.06 , 8.06 , 8.06 , 8.06 , 8.06 , 8.06 , 8.06 ],
#        [8.052, 8.052, 8.052, 8.052, 8.052, 8.052, 8.052, 8.052],
#        [8.062, 8.062, 8.062, 8.062, 8.062, 8.062, 8.062, 8.062],
#        [8.049, 8.049, 8.049, 8.049, 8.049, 8.049, 8.049, 8.049],
#        [8.037, 8.037, 8.037, 8.037, 8.037, 8.037, 8.037, 8.037],
#        [8.041, 8.041, 8.041, 8.041, 8.041, 8.041, 8.041, 8.041],
#        [8.042, 8.042, 8.042, 8.042, 8.042, 8.042, 8.042, 8.042],
#        [8.047, 8.047, 8.047, 8.047, 8.047, 8.047, 8.047, 8.047],
#        [8.037, 8.037, 8.037, 8.037, 8.037, 8.037, 8.037, 8.037],
#        [8.033, 8.033, 8.033, 8.033, 8.033, 8.033, 8.033, 8.033],
# ...

# %%
power_conv = np.empty((I,2))
for i in range(I):
    power_conv[i,:] = np.mean(Pump_Power_values[:i,:])
Pump_Power_values
# Out:
# array([[47039.897, 37124.748],
#        [47039.897, 37390.837],
#        [47039.897, 37354.864],
#        [47039.897, 37277.034],
#        [47039.897, 37119.036],
#        [47039.897, 37358.675],
#        [47039.897, 37371.097],
#        [47039.897, 37088.586],
#        [47039.897, 37383.575],
#        [47039.897, 37235.427],
#        [47039.897, 37402.584],
#        [47039.897, 37378.826],
#        [47039.897, 37156.081],
#        [47039.897, 37425.812],
#        [47039.897, 37205.805],
#        [47039.897, 37400.479],
#        [47039.897, 37154.981],
#        [47039.897, 37263.659],
#        [47039.897, 37551.355],
#        [47039.897, 37315.422],
#        [47039.897, 37291.959],
#        [47039.897, 37255.891],
#        [47039.897, 37201.781],
#        [47039.897, 37309.077],
#        [47039.897, 37265.751],
#        [47039.897, 37392.538],
#        [47039.897, 37125.276],
#        [47039.897, 37247.705],
#        [47039.897, 37256.109],
#        [47039.897, 36967.362],
# ...

# %%
plt.figure(figsize=(12, 6))
plt.subplot(211)
plt.plot(pressure_conv, c='red')
plt.subplot(212)
plt.plot(power_conv, c='green')

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ### Part E of Problem 5
#
# e) Consider what happens if water temperature ranges from 5◦C to 30◦C. Modify your ﬂuid prop-erties in the input ﬁle for each of these two limiting cases, then rerun your MC simulation. Report the uncertainties in pressure throughout the system based on your MC simulation as well as the uncertainty in required pumping power at the supply node 5 at the diﬀerent temperatures. Compare these to your results from part d) and discuss what eﬀect does temperature have on your results?
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
values_of_pressure, values_of_power = Variance(All_Pressure_values, Pump_Power_values)
values_of_pressure
# Out:
# [0.0006811280029700785,
#  0.010901420959759944,
#  0.011426361687979477,
#  0.0013396171572839966,
#  0.010928839762365973,
#  0.0021889336111191836,
#  0.21447099660502417,
#  0.0]

# %%
std_pressure, std_power = StandardDeviation(All_Pressure_values, Pump_Power_values)
std_pressure
# Out:
# [0.02603310129345384,
#  0.10414851825619578,
#  0.10662659086522264,
#  0.03650916421253131,
#  0.10427941102420048,
#  0.04666892909702972,
#  0.46195090823809304,
#  0.0]

# %%
mean_pressure, mean_power = Mean(All_Pressure_values, Pump_Power_values)
np.array(mean_pressure)
# Out:
# array([10.007,  6.971,  7.466, 10.119,  6.973, 10.326,  2.157, 10.21 ])

# %%
df_pressure_var = pd.DataFrame(data=np.array(values_of_pressure).reshape(-1, 1), columns=["T20"])
df_pressure_var.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_97471_row0_col0, #T_97471_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_97471_row1_col0, #T_97471_row2_col0, #T_97471_row4_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_97471_row3_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_97471_row5_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_97471_row6_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_97471">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97471_level0_col0" class="col_heading level0 col0" >T20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97471_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97471_row0_col0" class="data row0 col0" >0.000681</td>
#     </tr>
#     <tr>
#       <th id="T_97471_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
df_power_var = pd.DataFrame(data=np.array(values_of_power).reshape(-1, 1), columns=["T20"])
df_pressure_std = pd.DataFrame(data=np.array(std_pressure).reshape(-1, 1), columns=["T20"])
df_pressure_std.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d73f9_row0_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_d73f9_row1_col0, #T_d73f9_row4_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_d73f9_row2_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_d73f9_row3_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_d73f9_row5_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_d73f9_row6_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d73f9_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d73f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d73f9_level0_col0" class="col_heading level0 col0" >T20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d73f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d73f9_row0_col0" class="data row0 col0" >0.026033</td>
#     </tr>
#     <tr>
# ...

# %%
df_power_std = pd.DataFrame(data=np.array(std_power).reshape(-1, 1), columns=["T20"])
df_pressure_mean = pd.DataFrame(data=np.array(mean_pressure).reshape(-1, 1), columns=["T20"])
df_pressure_mean.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6a182_row0_col0 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_6a182_row1_col0, #T_6a182_row4_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_6a182_row2_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_6a182_row3_col0 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_6a182_row5_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6a182_row6_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6a182_row7_col0 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6a182">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a182_level0_col0" class="col_heading level0 col0" >T20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a182_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a182_row0_col0" class="data row0 col0" >10.007463</td>
#     </tr>
#     <tr>
# ...

# %%
df_power_mean = pd.DataFrame(data=np.array(mean_power).reshape(-1, 1), columns=["T20"])
df_pressure_var.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b0f9c_row0_col0, #T_b0f9c_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b0f9c_row1_col0, #T_b0f9c_row2_col0, #T_b0f9c_row4_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_b0f9c_row3_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b0f9c_row5_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_b0f9c_row6_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b0f9c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0f9c_level0_col0" class="col_heading level0 col0" >T20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0f9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0f9c_row0_col0" class="data row0 col0" >0.000681</td>
#     </tr>
#     <tr>
#       <th id="T_b0f9c_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Set Temperature to 5 Degree in WNTR Simulation
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
wn_5_degree = wntr.network.WaterNetworkModel(inp_file)
rho = 999.93  #[kg/m^3]
wn_5_degree.options.hydraulic.specific_gravity = 999.93/1000
wn_5_degree.options.hydraulic.viscosity = 1.519 * 1e-6 /1.004 * 1e-6

# %%
calculate_All_Pressure, calculate_Pump_Power = MonteCarloSimulationWorking(wn,0.02,0.02,True,I)
calculate_var_pressure, calculate_var_power = Variance(All_Pressure_values, Pump_Power_values)
calculate_std_pressure, calculate_std_power = StandardDeviation(All_Pressure_values, Pump_Power_values)
calculate_mean_pressure, calculate_mean_power = Mean(All_Pressure_values, Pump_Power_values)

# %%
df_pressure_var['T5'] = calculate_var_pressure
df_power_var['T5'] = calculate_var_power
df_pressure_std['T5'] = calculate_std_pressure
df_power_std['T5'] = calculate_std_power
df_pressure_mean['T5'] = calculate_mean_pressure
df_power_mean['T5'] = calculate_mean_power

# %%
df_power_mean.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_50f7a_row0_col0, #T_50f7a_row0_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_50f7a_row1_col0, #T_50f7a_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_50f7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50f7a_level0_col0" class="col_heading level0 col0" >T20</th>
#       <th id="T_50f7a_level0_col1" class="col_heading level0 col1" >T5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50f7a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50f7a_row0_col0" class="data row0 col0" >47039.897253</td>
#       <td id="T_50f7a_row0_col1" class="data row0 col1" >47039.897253</td>
#     </tr>
#     <tr>
#       <th id="T_50f7a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50f7a_row1_col0" class="data row1 col0" >37296.180222</td>
# ...

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Set Temperature to 30 Degree in WNTR Simulation
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
wn = wntr.network.WaterNetworkModel(inp_file)
rho = 995.65 #[kg/m^3]
wn.options.hydraulic.specific_gravity = 995.65/1000  # Density at 30 C / Density at 20 C (1000)
wn.options.hydraulic.viscosity = 0.7978 * 1e-6 /1.004 * 1e-6  #Viscosity at 30 C / Viscosity at 20 C (1.004 mPa.s)

# %%
calculate_All_Pressure, calculate_Pump_Power = MonteCarloSimulationWorking(wn,0.02,0.02,True,I)
calculate_var_pressure, calculate_var_power = Variance(calculate_All_Pressure, calculate_Pump_Power)
calculate_std_pressure, calculate_std_power = StandardDeviation(calculate_All_Pressure, calculate_Pump_Power)
calculate_mean_pressure, calculate_mean_power = Mean(calculate_All_Pressure, calculate_Pump_Power)

# %%
df_pressure_var['T30'] = calculate_var_pressure
df_power_var['T30'] = calculate_var_power
df_pressure_std['T30'] = calculate_std_pressure
df_power_std['T30'] = calculate_std_power
df_pressure_mean['T30'] = calculate_mean_pressure
df_power_mean['T30'] = calculate_mean_power

# %%
df_pressure_var.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_dba9b_row0_col0, #T_dba9b_row0_col1, #T_dba9b_row0_col2, #T_dba9b_row7_col0, #T_dba9b_row7_col1, #T_dba9b_row7_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_dba9b_row1_col0, #T_dba9b_row1_col1, #T_dba9b_row2_col0, #T_dba9b_row2_col1, #T_dba9b_row4_col0, #T_dba9b_row4_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_dba9b_row1_col2, #T_dba9b_row2_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_dba9b_row3_col0, #T_dba9b_row3_col1, #T_dba9b_row3_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_dba9b_row4_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_dba9b_row5_col0, #T_dba9b_row5_col1, #T_dba9b_row5_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_dba9b_row6_col0, #T_dba9b_row6_col1, #T_dba9b_row6_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dba9b">
#   <thead>
#     <tr>
# ...

# %%
df_pressure_std.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_7b718_row0_col0, #T_7b718_row0_col1, #T_7b718_row0_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_7b718_row1_col0, #T_7b718_row1_col1, #T_7b718_row4_col0, #T_7b718_row4_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_7b718_row1_col2, #T_7b718_row2_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_7b718_row2_col0, #T_7b718_row2_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_7b718_row3_col0, #T_7b718_row3_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_7b718_row3_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_7b718_row4_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_7b718_row5_col0, #T_7b718_row5_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_7b718_row5_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_7b718_row6_col0, #T_7b718_row6_col1, #T_7b718_row6_col2 {
# ...

# %%
df_pressure_mean.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_1cd12_row0_col0, #T_1cd12_row0_col1, #T_1cd12_row0_col2 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_1cd12_row1_col0, #T_1cd12_row1_col1, #T_1cd12_row4_col0, #T_1cd12_row4_col1 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_1cd12_row1_col2, #T_1cd12_row4_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_1cd12_row2_col0, #T_1cd12_row2_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_1cd12_row2_col2 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_1cd12_row3_col0, #T_1cd12_row3_col1, #T_1cd12_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_1cd12_row5_col0, #T_1cd12_row5_col1, #T_1cd12_row5_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1cd12_row6_col0, #T_1cd12_row6_col1, #T_1cd12_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1cd12_row7_col0, #T_1cd12_row7_col1, #T_1cd12_row7_col2 {
# ...

# %%
df_power_var.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_61f52_row0_col0, #T_61f52_row0_col1, #T_61f52_row0_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_61f52_row1_col0, #T_61f52_row1_col1, #T_61f52_row1_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_61f52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61f52_level0_col0" class="col_heading level0 col0" >T20</th>
#       <th id="T_61f52_level0_col1" class="col_heading level0 col1" >T5</th>
#       <th id="T_61f52_level0_col2" class="col_heading level0 col2" >T30</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61f52_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61f52_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_61f52_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_61f52_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
# ...

# %%
df_power_std.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_05178_row0_col0, #T_05178_row0_col1, #T_05178_row0_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_05178_row1_col0, #T_05178_row1_col1, #T_05178_row1_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_05178">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05178_level0_col0" class="col_heading level0 col0" >T20</th>
#       <th id="T_05178_level0_col1" class="col_heading level0 col1" >T5</th>
#       <th id="T_05178_level0_col2" class="col_heading level0 col2" >T30</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05178_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05178_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_05178_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_05178_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
# ...

# %%
df_power_mean.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ef84d_row0_col0, #T_ef84d_row0_col1, #T_ef84d_row0_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ef84d_row1_col0, #T_ef84d_row1_col1, #T_ef84d_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ef84d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef84d_level0_col0" class="col_heading level0 col0" >T20</th>
#       <th id="T_ef84d_level0_col1" class="col_heading level0 col1" >T5</th>
#       <th id="T_ef84d_level0_col2" class="col_heading level0 col2" >T30</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef84d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef84d_row0_col0" class="data row0 col0" >47039.897253</td>
#       <td id="T_ef84d_row0_col1" class="data row0 col1" >47039.897253</td>
#       <td id="T_ef84d_row0_col2" class="data row0 col2" >46929.131964</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ### Part F of Problem 5
#
# f) Investigate the importance of considering each of the three sources of uncertainty. To check this, re-run simulation while setting one uncertainty at a time to be zero and see what eﬀect that has. Report results from each case and brieﬂy discuss your observations on how they change from your results in part d) and from case to case (i.e. which uncertainty has the most signiﬁcant eﬀect?).
#
# ## Removing diameter uncertainty
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
wn = wntr.network.WaterNetworkModel(inp_file)

# %%
All_Pressure_values, Pump_Power_values = MonteCarloSimulationWorking(wn,0.0,0.02,True,I)

# %%
var_pressure, var_power = Variance(All_Pressure_values, Pump_Power_values)
std_pressure, std_power = StandardDeviation(All_Pressure_values, Pump_Power_values)
mean_pressure, mean_power = Mean(All_Pressure_values, Pump_Power_values)

# %%
df_pressure_var['No diam'] = var_pressure
df_power_var['No diam'] = var_power
df_pressure_std['No diam'] = std_pressure
df_power_std['No diam'] = std_power
df_pressure_mean['No diam'] = mean_pressure
df_power_mean['No diam'] = mean_power

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Removing length uncertainty
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
wn = wntr.network.WaterNetworkModel(inp_file)

# %%
All_Pressure_values, Pump_Power_values = MonteCarloSimulationWorking(wn,0.02,0.0,True,I)

# %%
var_pressure, var_power = Variance(All_Pressure_values, Pump_Power_values)
std_pressure, std_power = StandardDeviation(All_Pressure_values, Pump_Power_values)
mean_pressure, mean_power = Mean(All_Pressure_values, Pump_Power_values)

# %%
df_pressure_var['No length'] = var_pressure
df_power_var['No length'] = var_power
df_pressure_std['No length'] = std_pressure
df_power_std['No length'] = std_power
df_pressure_mean['No length'] = mean_pressure
df_power_mean['No length'] = mean_power

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Removing roughness uncertainty
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
wn = wntr.network.WaterNetworkModel(inp_file)

# %%
All_Pressure_values, Pump_Power_values = MonteCarloSimulationWorking(wn,0.02,0.02,False,I)
var_pressure, var_power = Variance(All_Pressure_values, Pump_Power_values)
std_pressure, std_power = StandardDeviation(All_Pressure_values, Pump_Power_values)
mean_pressure, mean_power = Mean(All_Pressure_values, Pump_Power_values)

# %%
df_pressure_var['No rough'] = var_pressure
df_power_var['No rough'] = var_power
df_pressure_std['No rough'] = std_pressure
df_power_std['No rough'] = std_power
df_pressure_mean['No rough'] = mean_pressure
df_power_mean['No rough'] = mean_power

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Show All Data Frames
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
df_pressure_var.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5e7c5_row0_col0, #T_5e7c5_row0_col1, #T_5e7c5_row0_col2, #T_5e7c5_row0_col3, #T_5e7c5_row0_col4, #T_5e7c5_row0_col5, #T_5e7c5_row7_col0, #T_5e7c5_row7_col1, #T_5e7c5_row7_col2, #T_5e7c5_row7_col3, #T_5e7c5_row7_col4, #T_5e7c5_row7_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5e7c5_row1_col0, #T_5e7c5_row1_col1, #T_5e7c5_row2_col0, #T_5e7c5_row2_col1, #T_5e7c5_row2_col4, #T_5e7c5_row4_col0, #T_5e7c5_row4_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_5e7c5_row1_col2, #T_5e7c5_row1_col4, #T_5e7c5_row2_col2, #T_5e7c5_row4_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_5e7c5_row1_col3, #T_5e7c5_row2_col3, #T_5e7c5_row4_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_5e7c5_row1_col5, #T_5e7c5_row4_col2, #T_5e7c5_row4_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_5e7c5_row2_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# ...

# %%
df_pressure_std.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_3565a_row0_col0, #T_3565a_row0_col1, #T_3565a_row0_col2, #T_3565a_row0_col4, #T_3565a_row0_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_3565a_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_3565a_row1_col0, #T_3565a_row1_col1, #T_3565a_row1_col3, #T_3565a_row2_col3, #T_3565a_row4_col0, #T_3565a_row4_col1, #T_3565a_row4_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_3565a_row1_col2, #T_3565a_row2_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_3565a_row1_col4, #T_3565a_row4_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_3565a_row1_col5, #T_3565a_row4_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_3565a_row2_col0, #T_3565a_row2_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_3565a_row2_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_3565a_row2_col5 {
#   background-color: #8db0fe;
# ...

# %%
df_pressure_mean.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d5278_row0_col0, #T_d5278_row0_col1, #T_d5278_row0_col2, #T_d5278_row0_col5 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_d5278_row0_col3, #T_d5278_row0_col4 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_d5278_row1_col0, #T_d5278_row1_col1, #T_d5278_row4_col0, #T_d5278_row4_col1 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_d5278_row1_col2, #T_d5278_row4_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_d5278_row1_col3, #T_d5278_row1_col5, #T_d5278_row4_col3, #T_d5278_row4_col5 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_d5278_row1_col4, #T_d5278_row4_col4 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_d5278_row2_col0, #T_d5278_row2_col1, #T_d5278_row2_col3, #T_d5278_row2_col5 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_d5278_row2_col2 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_d5278_row2_col4 {
# ...

# %%
df_power_var.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e4646_row0_col0, #T_e4646_row0_col1, #T_e4646_row0_col2, #T_e4646_row0_col3, #T_e4646_row0_col4, #T_e4646_row0_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e4646_row1_col0, #T_e4646_row1_col1, #T_e4646_row1_col2, #T_e4646_row1_col3, #T_e4646_row1_col4, #T_e4646_row1_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e4646">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4646_level0_col0" class="col_heading level0 col0" >T20</th>
#       <th id="T_e4646_level0_col1" class="col_heading level0 col1" >T5</th>
#       <th id="T_e4646_level0_col2" class="col_heading level0 col2" >T30</th>
#       <th id="T_e4646_level0_col3" class="col_heading level0 col3" >No diam</th>
#       <th id="T_e4646_level0_col4" class="col_heading level0 col4" >No length</th>
#       <th id="T_e4646_level0_col5" class="col_heading level0 col5" >No rough</th>
#     </tr>
#   </thead>
# ...

# %%
df_power_std.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b06bd_row0_col0, #T_b06bd_row0_col1, #T_b06bd_row0_col2, #T_b06bd_row0_col3, #T_b06bd_row0_col4, #T_b06bd_row0_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b06bd_row1_col0, #T_b06bd_row1_col1, #T_b06bd_row1_col2, #T_b06bd_row1_col3, #T_b06bd_row1_col4, #T_b06bd_row1_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b06bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b06bd_level0_col0" class="col_heading level0 col0" >T20</th>
#       <th id="T_b06bd_level0_col1" class="col_heading level0 col1" >T5</th>
#       <th id="T_b06bd_level0_col2" class="col_heading level0 col2" >T30</th>
#       <th id="T_b06bd_level0_col3" class="col_heading level0 col3" >No diam</th>
#       <th id="T_b06bd_level0_col4" class="col_heading level0 col4" >No length</th>
#       <th id="T_b06bd_level0_col5" class="col_heading level0 col5" >No rough</th>
#     </tr>
#   </thead>
# ...

# %%
df_power_mean.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f587e_row0_col0, #T_f587e_row0_col1, #T_f587e_row0_col2, #T_f587e_row0_col3, #T_f587e_row0_col4, #T_f587e_row0_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f587e_row1_col0, #T_f587e_row1_col1, #T_f587e_row1_col2, #T_f587e_row1_col3, #T_f587e_row1_col4, #T_f587e_row1_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f587e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f587e_level0_col0" class="col_heading level0 col0" >T20</th>
#       <th id="T_f587e_level0_col1" class="col_heading level0 col1" >T5</th>
#       <th id="T_f587e_level0_col2" class="col_heading level0 col2" >T30</th>
#       <th id="T_f587e_level0_col3" class="col_heading level0 col3" >No diam</th>
#       <th id="T_f587e_level0_col4" class="col_heading level0 col4" >No length</th>
#       <th id="T_f587e_level0_col5" class="col_heading level0 col5" >No rough</th>
#     </tr>
#   </thead>
# ...

# %% [markdown]
# ### Part G of Problem 5
#
# g) Within each pipe, calculate viscous length scale (SSA will provide example upon request), wall shear stress and estimate if a super hydrophobic coating with damage threshold of 10 Pa of shear and manufactural with rams roughness of 100 µm might result in drag reduction in each pipe segment (Requires having roughness below ∼ 5 viscous length scales. For simplicity: assume that there would be a way to avoid entrainment of gas from the surface into the ﬂow and a way to supply gas to the surface at pipeline pressure – not necessarily achievable presently).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Viscous Length Scale
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
rho = 1000
nu = 1.004
damage_threshold = 10
eps_coating = 100 * 1e-6

# %% [markdown]
# <hr style="height:5px;border-width:0;color:red;background-color:red">
#
# ## Calculations for All Pipes
#
# <hr style="height:5px;border-width:0;color:red;background-color:red">

# %%
#Pipe 1:
tau1 = (abs(P_Pa_value[0]-P_Pa_value[1])*(pipes['D'][0]/2))/(2*pipes['L'][0]) # Wall Shear Stress 
Lv1 = nu * (rho/tau1)**0.5*1e6 # Viscous Length
Lv1_5= Lv1*5 # Viscous Length mutiply by 5
Lv1_5
# Out:
# 241766598.0473374

# %%
#Pipe 2:
tau2 = (abs(P_Pa_value[1]-P_Pa_value[2])*(pipes['D'][1]/2))/(2*pipes['L'][1]) # Wall Shear Stress 
Lv2 = nu * (rho/tau2)**0.5*1e6 # Viscous Length
Lv2_5= Lv2*5 # Viscous Length mutiply by 5
Lv2_5
# Out:
# 63915541.677512564

# %%
#Pipe 3:
tau3 = (abs(P_Pa_value[0]-P_Pa_value[2])*(pipes['D'][2]/2))/(2*pipes['L'][2]) # Wall Shear Stress 
Lv3 = nu * (rho/tau3)**0.5*1e6 # Viscous Length
Lv3_5= Lv3*5 # Viscous Length mutiply by 5
Lv3_5
# Out:
# 54001243.42364859

# %%
#Pipe 4:
tau4 = (abs(P_Pa_value[1]-P_Pa_value[3])*(pipes['D'][3]/2))/(2*pipes['L'][3]) # Wall Shear Stress 
Lv4 = nu * (rho/tau4)**0.5*1e6 # Viscous Length
Lv4_5= Lv4*5 # Viscous Length mutiply by 5
Lv4_5
# Out:
# 57762251.335364394

# %%
#Pipe 5:
tau5 = (abs(P_Pa_value[2]-P_Pa_value[3])*(pipes['D'][4]/2))/(2*pipes['L'][4]) # Wall Shear Stress 
Lv5 = nu * (rho/tau5)**0.5*1e6 # Viscous Length
Lv5_5= Lv5*5 # Viscous Length mutiply by 5
Lv5_5
# Out:
# 136956006.40225458

# %%
#Pipe 6:
tau6 = (abs(P_Pa_value[4]-P_Pa_value[3])*(pipes['D'][5]/2))/(2*pipes['L'][5]) # Wall Shear Stress 
Lv6 = nu * (rho/tau6)**0.5*1e6 # Viscous Length
Lv6_5= Lv6*5 # Viscous Length mutiply by 5
Lv6_5
# Out:
# 137802111.01447886

# %%
#Pipe 7:
tau7 = (abs(P_Pa_value[3]-P_Pa_value[5])*(pipes['D'][6]/2))/(2*pipes['L'][6]) # Wall Shear Stress 
Lv7 = nu * (rho/tau7)**0.5*1e6 # Viscous Length
Lv7_5= Lv7*5 # Viscous Length mutiply by 5
Lv7_5
# Out:
# 80180696.16178533

# %%
#Pipe 8:
tau8 = (abs(P_Pa_value[2]-P_Pa_value[5])*(pipes['D'][7]/2))/(2*pipes['L'][7]) # Wall Shear Stress 
Lv8 = nu * (rho/tau8)**0.5*1e6 # Viscous Length
Lv8_5= Lv8*5 # Viscous Length mutiply by 5
Lv8_5
# Out:
# 59943341.07147899

# %%
#Pipe 9:
tau9 = (abs(P_Pa_value[4]-P_Pa_value[5])*(pipes['D'][8]/2))/(2*pipes['L'][8]) # Wall Shear Stress 
Lv9 = nu * (rho/tau9)**0.5*1e6 # Viscous Length
Lv9_5= Lv9*5 # Viscous Length mutiply by 5
Lv9_5
# Out:
# 72278801.51377

# %%
#Pipe 10:
tau10 = (abs(P_Pa_value[4]-P_Pa_value[6])*(pipes['D'][9]/2))/(2*pipes['L'][9]) # Wall Shear Stress 
Lv10 = nu * (rho/tau10)**0.5*1e6 # Viscous Length
Lv10_5= Lv10*5 # Viscous Length mutiply by 5
Lv10_5
# Out:
# 822251660.0967048

# %%
#Pipe 11:
tau11 = (abs(P_Pa_value[6]-P_Pa_value[5])*(pipes['D'][10]/2))/(2*pipes['L'][10]) # Wall Shear Stress 
Lv11 = nu * (rho/tau11)**0.5*1e6 # Viscous Length
Lv11_5= Lv11*5 # Viscous Length mutiply by 5
Lv11_5
# Out:
# 101854561.4328194

# %%
#Pipe 12:
tau12 = (abs(P_Pa_value[5]-P_Pa_value[7])*(pipes['D'][11]/2))/(2*pipes['L'][11]) # Wall Shear Stress 
Lv12 = nu * (rho/tau12)**0.5*1e6 # Viscous Length
Lv12_5= Lv12*5 # Viscous Length mutiply by 5
Lv12_5
# Out:
# 32170258.248903938

# %%
#Pipe 13:
tau13 = (abs(P_Pa_value[6]-P_Pa_value[7])*(pipes['D'][11]/2))/(2*pipes['L'][11]) # Wall Shear Stress 
Lv13 = nu * (rho/tau13)**0.5*1e6 # Viscous Length
Lv13_5= Lv13*5 # Viscous Length mutiply by 5
Lv13_5
# Out:
# 34116553.83452943

# %%
tau = [tau1, tau2, tau3, tau4, tau5, tau6, tau7, tau8, tau9, tau10, tau11, tau12, tau13]
df_tau = pd.DataFrame()
df_tau['\u03C4'] = tau
df_tau.T.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_803d1_row0_col0, #T_803d1_row0_col1, #T_803d1_row0_col2, #T_803d1_row0_col3, #T_803d1_row0_col4, #T_803d1_row0_col5, #T_803d1_row0_col6, #T_803d1_row0_col7, #T_803d1_row0_col8, #T_803d1_row0_col9, #T_803d1_row0_col10, #T_803d1_row0_col11, #T_803d1_row0_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_803d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_803d1_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_803d1_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_803d1_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_803d1_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_803d1_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_803d1_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_803d1_level0_col6" class="col_heading level0 col6" >6</th>
# ...

# %%
Lv = [Lv1, Lv2, Lv3, Lv4, Lv5, Lv6, Lv7, Lv8, Lv9, Lv10, Lv11, Lv12, Lv13]
df_Lv = pd.DataFrame()
df_Lv['\u03B7'] = Lv
df_Lv.T.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_91670_row0_col0, #T_91670_row0_col1, #T_91670_row0_col2, #T_91670_row0_col3, #T_91670_row0_col4, #T_91670_row0_col5, #T_91670_row0_col6, #T_91670_row0_col7, #T_91670_row0_col8, #T_91670_row0_col9, #T_91670_row0_col10, #T_91670_row0_col11, #T_91670_row0_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_91670">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91670_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_91670_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_91670_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_91670_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_91670_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_91670_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_91670_level0_col6" class="col_heading level0 col6" >6</th>
# ...

# %%
Lv_5 = [Lv1_5, Lv2_5, Lv3_5, Lv4_5, Lv5_5, Lv6_5, Lv7_5, Lv8_5, Lv9_5, Lv10_5, Lv11_5, Lv12_5, Lv13_5]
df_Lv_5 = pd.DataFrame()
df_Lv_5['5\u03B7'] = Lv_5
df_Lv_5.T.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_2c77b_row0_col0, #T_2c77b_row0_col1, #T_2c77b_row0_col2, #T_2c77b_row0_col3, #T_2c77b_row0_col4, #T_2c77b_row0_col5, #T_2c77b_row0_col6, #T_2c77b_row0_col7, #T_2c77b_row0_col8, #T_2c77b_row0_col9, #T_2c77b_row0_col10, #T_2c77b_row0_col11, #T_2c77b_row0_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2c77b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c77b_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_2c77b_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_2c77b_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_2c77b_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_2c77b_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_2c77b_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_2c77b_level0_col6" class="col_heading level0 col6" >6</th>
# ...
