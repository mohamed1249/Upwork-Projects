# %% [markdown]
# # YOLOv5
#
# YOLOv5 is an object detection model that can detect multiple objects in an image. The code for training and testing the model is available on GitHub.
#
# ## Code
#
# To install the necessary dependencies and train the model, the following code can be used:

# %% [markdown]
# ### Installing dependencies:

# %%
# Clone the yolov5 repository using Git
# !git clone https://github.com/ultralytics/yolov5

# Install the necessary dependencies for the yolov5 repository using pip
# !pip install -U -r yolov5/requirements.txt 

# Change the working directory to the cloned yolov5 repository
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# Requirement already satisfied: gitpython>=3.1.30 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 5)) (3.1.31)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 7)) (1.24.3)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 8)) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 9)) (9.5.0)
# Requirement already satisfied: psutil in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 11)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 12)) (2.30.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 13)) (1.10.1)
# Requirement already satisfied: thop>=0.1.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.7.0 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 15)) (2.0.0)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 16)) (0.15.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 17)) (4.65.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 26)) (2.0.1)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 27)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from -r yolov5/requirements.txt (line 41)) (67.7.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from gitpython>=3.1.30->-r yolov5/requirements.txt (line 5)) (4.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (5.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2022.12.7)
# Requirement already satisfied: filelock in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (3.8.0)
# Requirement already satisfied: typing-extensions in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (4.4.0)
# Requirement already satisfied: sympy in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (1.11.1)
# Requirement already satisfied: networkx in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (2.8.6)
# Requirement already satisfied: jinja2 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: colorama in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from tqdm>=4.64.0->-r yolov5/requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 26)) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 26)) (2022.5)
# Requirement already satisfied: six in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from cycler>=0.10->matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r yolov5/requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (3.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from jinja2->torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\laptop world\appdata\local\programs\python\python39\lib\site-packages (from sympy->torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (1.2.1)
# c:\python\projects\Upwork-Projects\Sara RCNN\YOLO\yolov5\yolov5

# %% [markdown]
# # Training the model:

# %%
# Train YOLOv5 object detection model with specified configuration and hyperparameters
# !python train.py --img 640 --batch 32 --epochs 100 --data data.yaml --cfg models/yolov5s.yaml --weights models/yolov5s.pt --name yolo_model --nosave --cache
# Out:
# train: weights=models/yolov5s.pt, cfg=models/yolov5s.yaml, data=data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=8, batch_size=8, imgsz=416, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=yolo_model, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# Traceback (most recent call last):
#   File "c:\python\projects\Upwork-Projects\Sara RCNN\YOLO\yolov5\yolov5\train.py", line 642, in <module>
#     main(opt)
#   File "c:\python\projects\Upwork-Projects\Sara RCNN\YOLO\yolov5\yolov5\train.py", line 506, in main
#     check_file(opt.data), check_yaml(opt.cfg), check_yaml(opt.hyp), str(opt.weights), str(opt.project)  # checks
#   File "c:\python\projects\Upwork-Projects\Sara RCNN\YOLO\yolov5\yolov5\utils\general.py", line 508, in check_file
#     assert len(files), f'File not found: {file}'  # assert file was found
# AssertionError: File not found: data.yaml

# %% [markdown]
# ## Validating the model:

# %% [markdown]
# To validate the trained model and test it on images, the following code can be used:

# %%
# !python yolov5/val.py --data yolov5/data.yaml --weights last.pt

# %% [markdown]
# ## Detectening:

# %%
# !python detect.py --source "data\validation\images\9a1b9061-0697F00000tQ1RYQA0-September-30-2021-15_50_20-AEST-1000.jpg" --weights runs/train/yolo_model4/weights/last.pt --conf 0.5
# Out:
# detect: weights=['yolov5/runs/train/yolo_model4/weights/last.pt'], source=data\validation\images\9a1b9061-0697F00000tQ1RYQA0-September-30-2021-15_50_20-AEST-1000.jpg, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# git: 'RCNN\YOLO\yolov5' is not a git command. See 'git --help'.
# YOLOv5  2023-5-5 Python-3.9.4 torch-2.0.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 C:\python\projects\Upwork-Projects\Sara RCNN\YOLO\data\validation\images\9a1b9061-0697F00000tQ1RYQA0-September-30-2021-15_50_20-AEST-1000.jpg: 640x480 3 Humans, 2 PFD (lifejacket) s, 3 PWCs, 3 Registration Numbers, 2 Structures, 152.0ms
# Speed: 0.0ms pre-process, 152.0ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5\runs\detect\exp4

# %%
import os   # Import the os module to execute shell commands
import time # Import the time module to pause the execution of the script


for img in os.listdir(r"New_DataSet\New_DataSet"):
    # Loop over all the images in the "data/validation/images" directory
    # and store the filename in the variable "img"

    os.popen(fr'python yolov5/detect.py --source "New_DataSet\New_DataSet\{img}" --weights last.pt --conf 0.1')
    # Execute the shell command to run the YOLOv5 model on the current image.
    # The "--source" argument specifies the input image file, "--weights" specifies
    # the pre-trained weights file, and "--conf" specifies the minimum confidence
    # threshold for the detected objects.

    time.sleep(6)
    # Pause the execution of the script for 6 seconds to allow time for the model
    # to detect objects in the current image.

    print(img, ' Done!')
    # Print a message to indicate that the detection for the current image is done.
# Out:
# 20230407_093847.jpg  Done!
# 20230407_093854M.jpg  Done!
# 20230407_093855.jpg  Done!
# 20230407_093902M.jpg  Done!
# 20230407_093903.jpg  Done!
# 20230407_093910M.jpg  Done!
# 20230407_093911.jpg  Done!
# 20230407_093935.jpg  Done!
# 20230407_093942M (1).jpg  Done!
# 20230407_093942M.jpg  Done!
# 20230407_093943.jpg  Done!
# 20230407_093944M.jpg  Done!
# 20230407_093945.jpg  Done!
# 20230407_093952M.jpg  Done!
# 20230407_093953.jpg  Done!
# 20230407_093959M.jpg  Done!
# 20230407_094000.jpg  Done!
# 20230414_110141M.jpg  Done!
# 20230414_110146M.jpg  Done!
# 20230414_110154M.jpg  Done!
# 20230414_110159M.jpg  Done!
# 20230414_111842M.jpg  Done!
# 20230414_111850M.jpg  Done!
# 20230414_111856M.jpg  Done!
# 20230414_111936M.jpg  Done!
# 20230414_111942M.jpg  Done!
# 20230414_111957M.jpg  Done!
# 20230414_112003M.jpg  Done!
# 20230414_112540M.jpg  Done!
# 20230414_112643M.jpg  Done!
# 20230414_112702M.jpg  Done!
# 20230414_112708M.jpg  Done!
# 20230414_113146M.jpg  Done!
# 20230414_113154M.jpg  Done!
# 20230414_113204M.jpg  Done!
# 20230414_113212M.jpg  Done!
# 20230414_113220M.jpg  Done!
# 20230414_114201M.jpg  Done!
# 20230414_114208M.jpg  Done!
# 20230414_114223M.jpg  Done!
# 20230414_114231M.jpg  Done!
# 20230414_121843M.jpg  Done!
# 20230414_121902M.jpg  Done!
# 20230414_121910M.jpg  Done!
# 20230414_121928M.jpg  Done!
# 20230414_121935M.jpg  Done!
# 20230414_121941M.jpg  Done!
# 20230414_121952M.jpg  Done!
# 20230414_121958M.jpg  Done!
# 20230414_122037M.jpg  Done!
# 20230414_122044M.jpg  Done!
# 20230414_122103M.jpg  Done!
# 20230414_122415M.jpg  Done!
# 20230414_122422M.jpg  Done!
# 20230414_122429M.jpg  Done!
# 20230414_122435M.jpg  Done!
# 20230414_123059M.jpg  Done!
# 20230414_123105M.jpg  Done!
# 20230414_123115M.jpg  Done!
# 20230414_123123M.jpg  Done!
# 20230414_123129M.jpg  Done!
# 20230414_123136M.jpg  Done!
# 20230414_150829M.jpg  Done!
# 20230414_150835M.jpg  Done!
# 20230414_150842M.jpg  Done!
# 20230414_150847M.jpg  Done!
# 20230414_150854M.jpg  Done!
# 20230414_150901M.jpg  Done!
# 20230414_150908M.jpg  Done!
# 20230414_150914M.jpg  Done!
# 20230414_150921M.jpg  Done!
# 20230414_150927M.jpg  Done!
# 20230414_150933M.jpg  Done!
# 20230414_150939M.jpg  Done!
# 20230414_150945M.jpg  Done!
# 20230414_150953M.jpg  Done!
# 20230414_151000M (1).jpg  Done!
# 20230414_151000M.jpg  Done!
# 20230414_151011M.jpg  Done!
# 20230414_151019M.jpg  Done!
# 20230414_151025M.jpg  Done!
# 20230414_151232M.jpg  Done!
# 20230414_151236M.jpg  Done!
# 20230414_151238M-GF959.jpg  Done!
# 20230414_151242M.jpg  Done!
# 20230414_151248M.jpg  Done!
# 20230414_161337M (1).jpg  Done!
# 20230414_161337M.jpg  Done!
# 20230414_161344M.jpg  Done!
# L1_20230407_091513M.jpg  Done!
# L1_20230407_091514.jpg  Done!
# L1_20230407_091521M.jpg  Done!
# L1_20230407_091522.jpg  Done!
# L1_20230407_091530M.jpg  Done!
# L1_20230407_091531 (1).jpg  Done!
# L1_20230407_091531.jpg  Done!
# L1_20230407_091538M.jpg  Done!
# L1_20230407_091540.jpg  Done!
# L1_20230407_091603M.jpg  Done!
# L1_20230407_091605.jpg  Done!
# L1_20230407_091612M.jpg  Done!
# L1_20230407_091613.jpg  Done!
# L1_20230407_091721M.jpg  Done!
# L1_20230407_091722.jpg  Done!
# L1_20230407_094132.jpg  Done!
# L1_20230407_094139M.jpg  Done!
# L1_20230407_094140.jpg  Done!
# R1_20230407_091826M.jpg  Done!
# R1_20230407_091827.jpg  Done!
# R1_20230407_091834M.jpg  Done!
# R1_20230407_091835.jpg  Done!
# R1_20230407_091841M.jpg  Done!
# R1_20230407_091842.jpg  Done!
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Old_DataSet Testing and validation Performance Matrix:

# %% [markdown]
# ### Now we're going to test our model on the Validation dataset as it's data that the model has never seen before and also it got true labels that we can compare our model's predictions to.

# %%
# Run validation script for YOLOv5
# !python yolov5/val.py --data data.yaml --weights last.pt
# Out:
# val: data=/content/drive/MyDrive/data.yaml, weights=['/content/yolov5/runs/train/yolo_model4/weights/last.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=../runs/val, name=exp, exist_ok=False, half=False, dnn=False
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning /content/drive/MyDrive/data/validation/labels.cache... 975 images, 0 backgrounds, 0 corrupt: 100% 975/975 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 31/31 [00:27<00:00,  1.15it/s]
#                    all        975       4318      0.939      0.832      0.861      0.625
#          Cabin Cruiser        975        167      0.996      0.994      0.995      0.848
#            Canoe/Kayak        975         79      0.998      0.924      0.978      0.619
#             Commercial        975          6      0.818          1      0.995      0.899
#               Half Cab        975        398      0.972      0.967      0.991      0.831
#                  Human        975       1563      0.945      0.867      0.908      0.598
#                   Open        975        236      0.922      0.951      0.964      0.784
#                  Other        975          2          1          0     0.0717     0.0645
#      PFD (lifejacket)         975        563      0.922      0.773      0.827      0.447
#                    PWC        975        263      0.954      0.942      0.947      0.656
#    Registration Number        975        686      0.903      0.878      0.895       0.52
#              Structure        975        355      0.903      0.854      0.896      0.603
# Speed: 0.3ms pre-process, 5.0ms inference, 2.7ms NMS per image at shape (32, 3, 640, 640)
# Results saved to ../runs/val/exp2

# %% [markdown]
# These results appear to be from an object detection model trained to detect various objects within images, with evaluation metrics reported for each class of object.
#
# The table lists the following information for each class:
#
# - The number of images in the test set that contain instances of the object class.
# - The total number of instances of the object class detected in the test set.
# - The precision (P) and recall (R) values for the object class, which are commonly used evaluation metrics for object detection models. Precision measures the fraction of detected instances that are correct, while recall measures the fraction of true instances that were detected.
# - The mAP50 and mAP50-95 values for the object class, which are the mean average precision over all possible intersection over union (IoU) thresholds from 0.5 to 0.95, with a step size of 0.05. The mAP50 is calculated using only IoU thresholds of 0.5, while mAP50-95 uses thresholds from 0.5 to 0.95. These metrics provide a measure of overall detection accuracy for the model.
#
# The "all" row in the table provides aggregated metrics over all object classes. It shows that the model achieved an overall precision of 0.939 and recall of 0.832, resulting in an overall mAP50 of 0.861 and mAP50-95 of 0.625.
#
# For each individual object class, the model achieved varying levels of performance. For example, the "Cabin Cruiser" class achieved high precision and recall values, resulting in high mAP50 and mAP50-95 values, indicating that the model was able to accurately detect instances of this object class. However, the "Other" class achieved perfect precision but zero recall, indicating that the model was able to correctly classify instances when they were present, but was not able to detect any instances in the test set.
#
# Overall, these results provide a snapshot of how well the object detection model performed in detecting different classes of objects in the test set.

# %% [markdown]
# #### From the apove results we can see that our model's accuracy on each class was as follow
# - Cabin Cruiser ->         99.5%
# - Canoe/Kayak    ->      97.8%
# - Commercial       ->    99.5%
# - Half Cab          ->   99.1%
# - Human       -> 90.8%
# - Open      ->  96.4%
# - PFD (lifejacket)       ->  82.7%
# -    PWC        94.7%
# - Registration Number      ->  89.5%
# - Structure        89.6%

# %% [markdown]
# #### Confusion Matrix:

# %% [markdown]
# ![confusion_matrix](confusion_matrix.png)

# %% [markdown]
# Looking at this confusio matrix of our model we can see some details:
# - our model predicted some Other as Cabin Cruiser class.
# - our model predicted Commercials was right!
# - our data hsd no Dinghies/Cats, Hire & Drive, House Boats, Kites, Rowings, SUPs, Ski Boats, Windsurfers or Yachts, so it would be better if we removed them from our classes as they may confuse our model.
# - our model wasn't the best in predicting Huemans as it only predicted 82% from them true, but we can improve this by giving it more data with Humans in it to train on.
# - our model predicted all Other class wrong, so I suggest we better remove it too from our classes.
# - our model wasn't the best in predicting PFDs as it only predicted 77% from them true, and predicted 16% of them as Background, but we can improve this by giving it more data with PFDs in it to train on.
# - our model predicted some Regestration numbers as Background class.

# %% [markdown]
# ![PR_curve](PR_curve.png)

# %% [markdown]
# The precision-recall (PR) curve is a graphical representation of the performance of a binary classifier, plotting precision and recall for different thresholds.
#
# Precision is the proportion of true positive predictions out of all positive predictions, while recall is the proportion of true positive predictions out of all actual positive instances. In other words, precision measures the accuracy of the positive predictions, while recall measures the completeness of the positive predictions.
#
# The PR curve is useful when there is an imbalance in the distribution of positive and negative instances in the data. It allows us to evaluate the trade-off between precision and recall for different thresholds, and to select the threshold that maximizes the F1 score, which is the harmonic mean of precision and recall.
#
# A perfect classifier would achieve a precision of 1.0 and a recall of 1.0, resulting in a PR curve that passes through the point (1.0, 1.0). A classifier that predicts at random would result in a PR curve that follows the line y = x (i.e., the diagonal of the plot), with an area under the curve (AUC) of 0.5.
#
# The area under the PR curve (AUC-PR) provides a single number that summarizes the overall performance of the classifier, with a higher AUC-PR indicating better performance.
#
# ### And for me, this PR_curve is very good and proves that our model can be relied on in detecting most of our classes.

# %%
# Importing necessary libraries
import matplotlib.pyplot as plt
import os

# Initializing counter variable n to 0
n = 0

# Iterating through each directory in the specified path
for d in os.listdir(r'yolov5\runs\detect'):
    
    # Iterating through each file in the directory
    for i in os.listdir(os.path.join(r'yolov5\runs\detect',d)):
        
        # Checking if the counter variable n is less than 10
        if n < 10:
            
            # Reading the image file using plt.imread() and displaying it using plt.imshow()
            img = plt.imread(os.path.join(r'yolov5\runs\detect',d,i))
            plt.imshow(img)
            plt.show()
            
            # Incrementing the counter variable n by 1
            n += 1
        
        # Breaking the loop if the counter variable n reaches 10
        else: 
            break

# %% [markdown]
# ![val_batch2_pred](val_batch2_pred.jpg)

# %% [markdown]
# ### New_DataSet_Testing_And_Validation:

# %%
import os   # Import the os module to execute shell commands
import time # Import the time module to pause the execution of the script


for img in os.listdir(r"images"):
    # Loop over all the images in the "data/validation/images" directory
    # and store the filename in the variable "img"

    os.popen(fr'python yolov5/detect_txt.py --source "images\{img}" --weights last.pt --conf 0.5 --save-txt --save-conf')
    # Execute the shell command to run the YOLOv5 model on the current image.
    # The "--source" argument specifies the input image file, "--weights" specifies
    # the pre-trained weights file, and "--conf" specifies the minimum confidence
    # threshold for the detected objects.

    time.sleep(6)
    # Pause the execution of the script for 6 seconds to allow time for the model
    # to detect objects in the current image.

    print(img, ' Done!')
    # Print a message to indicate that the detection for the current image is done.
# Out:
# CabinCruiser-05d6a512-2422-488e-8b01-c73c38ab7b72.jpg  Done!
# CabinCruiser-080b97b0-4dd0-4e82-a56d-0f5a2ab581a8.jpg  Done!
# CabinCruiser-090e7b77-6fbb-47be-bebc-8829deb9f10c.jpg  Done!
# CabinCruiser-0b4b849d-b697-4c4a-9592-d22f30af59fe.jpg  Done!
# CabinCruiser-0e4c6621-3af8-4fc2-8352-5ed7e80a1673.jpg  Done!
# CabinCruiser-1170bb3a-4cef-4060-961b-41eb410d35b1.jpg  Done!
# CabinCruiser-2a84d74e-1099-4527-a345-f3118345823a.jpg  Done!
# CabinCruiser-48293d59-e260-49fc-9a35-4ad3c43b3cd0.jpg  Done!
# CabinCruiser-4b1d8183-e005-4cce-ad1a-f101aea8ae0c.jpg  Done!
# CabinCruiser-4f03e0b8-b2aa-48cf-b545-497d92b55d4b.jpg  Done!
# CabinCruiser-4fc4f337-0de9-4abe-a92c-b310c2ceff06.jpg  Done!
# CabinCruiser-4fe91a48-6386-4dc2-9595-1a40bb72afd5.jpg  Done!
# CabinCruiser-64978b38-a343-49c9-a4b3-83fb367459d1.jpg  Done!
# CabinCruiser-6698516a-b982-4f44-883f-7738f810f063.jpg  Done!
# CabinCruiser-69ec4203-9fcb-495a-a92f-cba32a896373.jpg  Done!
# CabinCruiser-6fd1a20e-ed18-42c9-acd6-0b7f5003f829.jpg  Done!
# CabinCruiser-7081b81b-7d6e-4581-adf1-7b09acd9921e.jpg  Done!
# CabinCruiser-7945b067-037a-4e8f-9109-92d39247a69a.jpg  Done!
# CabinCruiser-8911850a-0cd1-4526-8df4-e6ddd33231b1.jpg  Done!
# CabinCruiser-8e7721f4-f8dc-4e4d-82b4-b1979f4e14cd.jpg  Done!
# CabinCruiser-906bd060-3674-440d-a1cc-8bbc6fd90780.jpg  Done!
# CabinCruiser-926cb0d9-f451-4e6c-9bac-5b4c9c11971e.jpg  Done!
# CabinCruiser-9ba02f6b-fe7b-44a3-b7c6-84fc30a5028e.jpg  Done!
# CabinCruiser-9d719c9a-d0ac-416b-89f7-adde86905f3d.jpg  Done!
# CabinCruiser-9fb9e2bb-7456-4c56-8f15-1f3ff463f6d2.jpg  Done!
# CabinCruiser-a06d10fb-1d61-4d2f-a8c5-1aaf1105f6e9.jpg  Done!
# CabinCruiser-a0fc5d2d-ccaf-4e00-9d1f-0108581bb132.jpg  Done!
# CabinCruiser-ad9205eb-4ce0-4657-9acd-18a4bd1143b7.jpg  Done!
# CabinCruiser-c767f2a8-cd87-4937-b4ae-dbdf66809742.jpg  Done!
# CabinCruiser-c83f55d4-7bab-46ce-8d07-24ce29f6ced2.jpg  Done!
# CabinCruiser-cb404ee8-aec1-4e98-8641-414931b4fc53.jpg  Done!
# CabinCruiser-e085dc22-ae7c-4bdc-924c-f1a263effa81.jpg  Done!
# CabinCruiser-e16ed89a-d067-417e-a8dc-3321cfa9bd73.jpg  Done!
# CabinCruiser-e2049002-61b7-4abe-aaaa-b4d1d9596643.jpg  Done!
# CabinCruiser-efaee890-4a66-45b3-a6a6-c4a8da85ac0a.jpg  Done!
# CabinCruiser-fcd24954-f31e-4a11-9695-69e5e3bb39a9.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_111429M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_111450M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_111459M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_111506M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_111821M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_111828M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_111842M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_111850M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_111856M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_111936M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_111942M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_111957M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_112003M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_112643M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_112702M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_112708M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_113146M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_113154M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_113204M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_113212M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_113220M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_114201M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_114208M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_114223M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_114231M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_121928M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_121935M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_121941M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_121952M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_121958M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_151232M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_151236M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_151238M-GF959.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_151242M.jpg  Done!
# CabinCruiserUnder5Kn - 20230414_151248M.jpg  Done!
# Commercial-072d575a-f6bf-4b01-a8bd-d338c185f7fe.jpg  Done!
# Commercial-0ee07619-6f53-4286-94a2-2b1fdda08b07.jpg  Done!
# Commercial-2a9c2fcb-81bd-40a0-9e15-5f33cc83e37b.jpg  Done!
# Commercial-395cd44f-c65b-45c0-b208-04e819f9ce0c.jpg  Done!
# Commercial-3c7e98e7-5f80-48d6-b0ae-0d6a60f8e2ca.jpg  Done!
# Commercial-41f52a2b-e9d1-40c5-b09a-7b09d8153b94.jpg  Done!
# Commercial-422061a8-062a-4ece-80c1-a9318c9f36fb.jpg  Done!
# Commercial-4aeb7aa9-3292-454b-b3f6-586a592eb4ab.jpg  Done!
# Commercial-4ead5c03-a499-4f58-bd5a-da6a21e4f66a.jpg  Done!
# Commercial-57586946-d585-41f8-a4d3-a42bfd2d854c.jpg  Done!
# Commercial-5b9b8104-8675-4522-b167-7504457b0b85.jpg  Done!
# Commercial-646316b6-f32c-4ad3-9b92-2497ac505326.jpg  Done!
# Commercial-71831ec5-2af5-4f50-95d4-3f517d45ce4b.jpg  Done!
# Commercial-769d0f35-a941-49a8-ac6a-1e8855998590.jpg  Done!
# Commercial-7bd5123d-9ee1-4ae6-b532-67fd0d44359f.jpg  Done!
# Commercial-ab18cb1b-be86-44dd-927f-536aee751cce.jpg  Done!
# Commercial-bacb712b-e49d-4acb-bced-ad2d2bb8ae22.jpg  Done!
# Commercial-bc7c9fbb-9759-472b-bb93-8f736740b837.jpg  Done!
# Commercial-bcd8a116-58dc-47ec-929b-e6310854a041.jpg  Done!
# Commercial-c4824241-99c4-4c69-b3b6-487894002270.jpg  Done!
# Commercial-c71c2027-0896-45c8-9589-ffabb2e23205.jpg  Done!
# Commercial-c779fca0-df9b-4c8e-9959-902a57b0d29d.jpg  Done!
# Commercial-cc4b9179-b05e-4135-a3d7-709acf87375a.jpg  Done!
# Commercial-d20f748b-0580-48e0-8ee8-05f2fd9c5bc4.jpg  Done!
# Commercial-d748ad71-3b19-4331-931e-a899bfae3676.jpg  Done!
# Commercial-d7f7a86f-72a6-4acb-b0b1-7eb3ac4f261f.jpg  Done!
# Commercial-ef1c8f00-2809-41ed-916e-fcea73e98f61.jpg  Done!
# Commercial-fca7d25d-2160-45d2-88d5-e3042f22f9d3.jpg  Done!
# HalfCab-041662ff-f8b1-46e2-93a2-ca073712239d.jpg  Done!
# HalfCab-077a7b0b-92ed-48a0-adad-ebba6c64ce13.jpg  Done!
# HalfCab-07ba74c2-3e4b-4d65-8c1b-9da608302189.jpg  Done!
# HalfCab-088f6404-4f14-4110-90ec-f69586dae5fc.jpg  Done!
# HalfCab-0dda499f-3214-491b-a2c3-b8483e8db859.jpg  Done!
# HalfCab-1882503d-82ff-4132-a90c-c40cc33ed47c.jpg  Done!
# HalfCab-18f278c0-08b7-4197-9762-368be410f1fd.jpg  Done!
# HalfCab-1918d8e9-c0a8-4dee-973b-fd34e74b48e4.jpg  Done!
# HalfCab-1fb9510d-a54d-48f6-b42a-cf087f733a30.jpg  Done!
# HalfCab-42f4c6df-8775-466d-844b-1d8f9d608d0d.jpg  Done!
# HalfCab-46bad860-3b57-40c6-b48a-22bdbbdf0386.jpg  Done!
# HalfCab-480e718a-b2e3-47d1-bed5-0819f4ddfbf5.jpg  Done!
# HalfCab-494f755b-7502-4d40-86a0-24c61656b1fa.jpg  Done!
# HalfCab-4baf0b71-910b-44a6-b56d-061701373524.jpg  Done!
# HalfCab-545fee69-8ca5-4e21-bf75-0d7d5442da75.jpg  Done!
# HalfCab-555de0ee-f24d-42b4-b793-891d1073a848.jpg  Done!
# HalfCab-5a5e2d3c-033e-4974-b864-978d86c75090.jpg  Done!
# HalfCab-60731b9f-5c06-415f-8d5d-df8326c35f9f.jpg  Done!
# HalfCab-62a69a3e-c4f0-4610-8ac0-89bc0dea8cac.jpg  Done!
# HalfCab-62f5b126-2d7e-4581-be66-f005ba5a519e.jpg  Done!
# HalfCab-643ce14c-9daa-4bf5-9348-92a57f64d3a8.jpg  Done!
# HalfCab-64b843c2-259e-4766-afb3-8c5ca654aa18.jpg  Done!
# HalfCab-653b1a6e-1496-4ddd-aba2-0b8e59cbf324.jpg  Done!
# HalfCab-732ddbaf-7218-49eb-ab60-b351cba5eaac.jpg  Done!
# HalfCab-84bd2440-408e-41cf-a5f9-d88c66a474ed.jpg  Done!
# HalfCab-8b42a456-1ed5-4435-a5e3-e97a133bb72d.jpg  Done!
# HalfCab-9d2a21fa-b07a-4210-9bae-56f300a068d9.jpg  Done!
# HalfCab-a51df15c-37e7-41b5-8eae-e73f961730cd.jpg  Done!
# HalfCab-c559d48e-e535-456c-baad-acb7130f108a.jpg  Done!
# HalfCab-c5ec702b-249b-4e9d-9121-4d24c96f5336.jpg  Done!
# HalfCab-e11a2105-427e-4492-9b91-2dabcf1a3fbc.jpg  Done!
# HalfCab-e11a39c0-b471-4243-9b64-1ad94187cffe.jpg  Done!
# HalfCab-e68359b1-3eff-4abf-807c-5d006433a77f.jpg  Done!
# HalfCab-e6ae2243-a776-4016-8023-dfc8c008fc35.jpg  Done!
# HalfCab-e9241625-ca1c-4ae5-8b99-f9ce3c19b4e6.jpg  Done!
# HalfCab-eabbdbf3-8914-44f5-a9b8-02fc6db8d573.jpg  Done!
# HalfCab-f80cc0d9-ee2e-402c-b319-f44279009946.jpg  Done!
# HalfCab-f8b08df3-37c2-4192-a00f-b53d85fc478f.jpg  Done!
# HalfCabUnder5Kn - 20230407_093847.jpg  Done!
# HalfCabUnder5Kn - 20230407_093854M.jpg  Done!
# HalfCabUnder5Kn - 20230407_093855.jpg  Done!
# HalfCabUnder5Kn - 20230407_093902M.jpg  Done!
# HalfCabUnder5Kn - 20230407_093903.jpg  Done!
# HalfCabUnder5Kn - 20230407_093910M.jpg  Done!
# HalfCabUnder5Kn - 20230407_093911.jpg  Done!
# HalfCabUnder5Kn - 20230414_121843M.jpg  Done!
# HalfCabUnder5Kn - 20230414_121902M.jpg  Done!
# HalfCabUnder5Kn - 20230414_121910M.jpg  Done!
# HalfCabUnder5Kn - L1_20230407_093846M.jpg  Done!
# HumanPowered - 20230414_110141M.jpg  Done!
# HumanPowered - 20230414_110146M.jpg  Done!
# HumanPowered - 20230414_110154M.jpg  Done!
# HumanPowered - 20230414_110159M.jpg  Done!
# HumanPowered - 20230414_122037M.jpg  Done!
# HumanPowered - 20230414_122044M.jpg  Done!
# HumanPowered - 20230414_122103M.jpg  Done!
# HumanPowered - 20230414_122415M.jpg  Done!
# HumanPowered - 20230414_122422M.jpg  Done!
# HumanPowered - 20230414_122429M.jpg  Done!
# HumanPowered - 20230414_122435M.jpg  Done!
# HumanPowered-05a13b35-27ce-49f9-83fb-46a5c121a7da.jpg  Done!
# HumanPowered-08ccde5a-88be-4056-9f86-130527e3777e.jpg  Done!
# HumanPowered-0ea24ab3-8f54-4c21-865c-023bee4f9cf1.jpg  Done!
# HumanPowered-0f10e455-9e25-4c33-9c5c-386af7c954dd.jpg  Done!
# HumanPowered-145f1d54-5a10-431c-978d-a99a5e361269.jpg  Done!
# HumanPowered-1efe6682-632a-469a-8f3e-ea2bd69b3b8a.jpg  Done!
# HumanPowered-26e62f3f-71ba-4d90-8ecf-8de66d73725a.jpg  Done!
# HumanPowered-2868c848-dc9b-4581-bc56-94e0de9e9d02.jpg  Done!
# HumanPowered-3f8c5198-2bda-44e4-8c5f-bf652f155b8f.jpg  Done!
# HumanPowered-418e76da-ede0-4354-94ec-50a7048690b3.jpg  Done!
# HumanPowered-43773453-7ab5-4eef-a8ad-5097a2be40e5.jpg  Done!
# HumanPowered-45b74f53-9e9a-470a-84f2-3baf978349bb.jpg  Done!
# HumanPowered-4930e774-7178-474f-a885-bf05777df500.jpg  Done!
# HumanPowered-4c0386f4-0aad-44c1-a66d-8f64dfc48a66.jpg  Done!
# HumanPowered-4f1141fa-fd26-4cd8-891f-4d5901cb1d6c.jpg  Done!
# HumanPowered-61f301ca-21ce-4004-a981-d9f6327edd78.jpg  Done!
# HumanPowered-6dd5d4c7-7d18-4a7d-9e43-68a9937a1be7.jpg  Done!
# HumanPowered-7643f054-b4da-47bb-af3b-89c3398ae1aa.jpg  Done!
# HumanPowered-7cff4e17-7698-46c2-8b27-d939629be462.jpg  Done!
# HumanPowered-82744ed7-e074-4462-966a-0644bf99f0ca.jpg  Done!
# HumanPowered-88f729aa-3934-49f7-8d88-bb39d67e92ce.jpg  Done!
# HumanPowered-9b3b3482-3ab6-48ec-a419-979b525101fa.jpg  Done!
# HumanPowered-a47e366b-c66e-4969-aa67-2d2149af5840.jpg  Done!
# HumanPowered-a8ceb264-d58f-4b94-9c2b-f62bfd1b9d82.jpg  Done!
# HumanPowered-aaa3b953-4ca4-4110-8467-c45540d4c23b.jpg  Done!
# HumanPowered-bba6de7c-df6f-4e02-a3c9-fe0884fe4440.jpg  Done!
# HumanPowered-cba7d5b1-701b-47a4-8dfe-7e94f4d8d361.jpg  Done!
# HumanPowered-cc329e98-b2e1-486b-ba67-830971c4a00c.jpg  Done!
# HumanPowered-d0af6998-ca03-480f-8133-aee3a2dee7b7.jpg  Done!
# HumanPowered-d783408a-cd28-45fe-b45e-3d2944b6150c.jpg  Done!
# HumanPowered-daa809a4-328f-4c04-a357-fa5a1ba35358.jpg  Done!
# HumanPowered-ddbdd793-dfb2-4a6f-acc9-6f519fe8f6db.jpg  Done!
# HumanPowered-e61455ed-eb0a-4173-9e5d-e53b5924224c.jpg  Done!
# HumanPowered-f7554ecb-b99e-4a56-9341-b815197cb167.jpg  Done!
# Open-00ccf85a-7fd7-4af9-bdd1-2902f16a4e50.jpg  Done!
# Open-00e2e364-eb5a-4e1d-8e5a-e72ca774b581.jpg  Done!
# Open-0b3f6d70-872f-4cf3-bebe-2144d79e3436.jpg  Done!
# Open-0c84a2ef-45ac-419c-81b9-6351521ffd2d.jpg  Done!
# Open-0e6283fc-c059-4a70-b616-d1573074fe80.jpg  Done!
# Open-1e4eb5c4-1129-4595-821c-2136b48583ad.jpg  Done!
# Open-2324ae39-a3d9-4ff3-afec-134686916e85.jpg  Done!
# Open-242b2b1b-8799-4a2a-9c4d-8271a4544fc7.jpg  Done!
# Open-255a6d24-3090-4c5b-a492-e01bd4739489.jpg  Done!
# Open-2ab8ca00-dee1-4a29-830a-e5c7ad70f964.jpg  Done!
# Open-36264d06-773b-4009-808f-e2a36875b4d0.jpg  Done!
# Open-3c37b93d-d1ba-42ae-9028-b3f439e5ca28.jpg  Done!
# Open-3e85ab5e-c21f-4edd-af01-f79a4f274de2.jpg  Done!
# Open-4018a1a6-1b3a-4cc9-8c9c-eec1fc614dcc.jpg  Done!
# Open-413716e4-b4da-4288-b62f-6d6644df771e.jpg  Done!
# Open-5071f5ef-ea3e-42fc-ab72-39bd92a154b3.jpg  Done!
# Open-581ec858-02c9-4f85-96d5-ed469d5c349e.jpg  Done!
# Open-60c2d7fb-f230-4e91-90eb-050f6fa30ded.jpg  Done!
# Open-60fa30d0-851d-4ca2-8038-5207f2846acc.jpg  Done!
# Open-63c3b938-beb4-4b9a-ba14-d8e3a45a625f.jpg  Done!
# Open-67c13d8e-d609-496e-a94d-0c01f25fd9ff.jpg  Done!
# Open-79e4f2c6-e331-4572-ace8-c6860732f29f.jpg  Done!
# Open-980de5e9-686c-4a12-8db6-ef4b8e726355.jpg  Done!
# Open-a3fb3eae-c667-4886-b987-250125a25e93.jpg  Done!
# Open-a82dd946-8bea-431a-90e0-3d20c30f142b.jpg  Done!
# Open-abbbbd09-d5b9-4be9-9b35-f7a5f536ef81.jpg  Done!
# Open-be2f4357-a50e-4b21-95a2-2928a5cbb7fc.jpg  Done!
# Open-c71bc3ce-17cf-41ab-bf70-e571a012bd14.jpg  Done!
# Open-c8c070c7-281e-4f0d-80f7-9d38561fb20f.jpg  Done!
# Open-cab1541f-9b8c-4763-93c5-620ec225493f.jpg  Done!
# Open-d52ca1b5-e901-42ed-ab9c-81b336c653cf.jpg  Done!
# Open-da564220-24fb-44f5-b80d-2d0f31532f22.jpg  Done!
# Open-db23fbb0-e581-48de-bf8c-da433a4f311f.jpg  Done!
# OpenUnder5kn - 20230407_093934M.jpg  Done!
# OpenUnder5kn - 20230407_093935.jpg  Done!
# OpenUnder5kn - 20230407_093944M.jpg  Done!
# OpenUnder5kn - 20230407_093945.jpg  Done!
# OpenUnder5kn - 20230407_093952M.jpg  Done!
# OpenUnder5kn - 20230407_093953.jpg  Done!
# OpenUnder5kn - 20230407_093959M.jpg  Done!
# OpenUnder5kn - 20230407_094000.jpg  Done!
# OpenUnder5kn - 20230414_112540M.jpg  Done!
# OpenUnder5kn - 20230414_123059M.jpg  Done!
# OpenUnder5kn - 20230414_123105M.jpg  Done!
# OpenUnder5kn - 20230414_123115M.jpg  Done!
# OpenUnder5kn - 20230414_123123M.jpg  Done!
# OpenUnder5kn - 20230414_123129M.jpg  Done!
# OpenUnder5kn - 20230414_123136M.jpg  Done!
# OpenUnder5kn - 20230414_161337M.jpg  Done!
# OpenUnder5kn - 20230414_161344M.jpg  Done!
# OpenUnder5kn - L1_20230407_091513M.jpg  Done!
# OpenUnder5kn - L1_20230407_091514.jpg  Done!
# OpenUnder5kn - L1_20230407_091521M.jpg  Done!
# OpenUnder5kn - L1_20230407_091522.jpg  Done!

# %%
# class_dict = {0: 'CabinCruiser', 1: 'HumanPowered', 4: 'HalfCab', 4: 'Open'}
class_dict = {'CabinCruiser': 0,'Commercial':2, 'HumanPowered': 1, 'Open': 4, 'HalfCab':4}

# %%
import os, cv2

labelslst = [] # Initialize empty list to store labels.
detectpath = r'yolov5/runs/detect' # Set path to directory containing experiment folders.
for expfolder in os.listdir(detectpath): # Iterate over experiment folders.
    for labelsfile in os.listdir(os.path.join(detectpath,expfolder,'labels')): # Iterate over label files in each experiment folder.
        with open(os.path.join(detectpath,expfolder,'labels',labelsfile), 'r') as file: # Open each label file.
            for line in file: # Iterate over lines in the label file.
                if int(line.replace('\n','').split(' ')[0]) in class_dict.values() and ' - ' not in labelsfile: # Check if the line contains a class ID that is present in the class dictionary.
                    classlst = line.replace('\n','').split(' ') # Split the line into a list.
                    classlst = [round(float(item),1) for item in classlst] # Convert each item in the list to a float and round to 1 decimal place.
                    predclass = [name for name,number in class_dict.items() if number == int(line.replace('\n','').split(' ')[0])][0].lower()  # Get the predicted class name from the class dictionary.
                    realclass = labelsfile.split('-')[0].lower().replace('under5kn','').replace('over5kn','').strip() # Get the real class name from the label file name.
                    classlst.insert(0,labelsfile.replace('.txt','.jpg')) # Add the image file name to the beginning of the list.
                    classlst.insert(2, predclass) # Add the predicted class name to the list.
                    classlst.insert(3, realclass) # Add the real class name to the list.
                    labelslst.append(classlst) # Append the list to the label list.

labelslst[0]
# Out:
# ['CabinCruiserUnder5Kn-3e7bd318-adea-4749-a5a8-418e1a2eae69.jpg',
#  4.0,
#  'open',
#  'cabincruiser',
#  0.1,
#  0.3,
#  0.2,
#  0.2,
#  0.9]

# %%
import pandas as pd  # Import the Pandas library

# Create a DataFrame from a list called `labelslst`, with specific column names
lablelsdf = pd.DataFrame(labelslst, columns=['image_name','pred_class_number','pred_class_name','real_class_name','bbox1','bbox2','bbox3','bbox4','confidence_score'])

# Drop duplicate rows in the DataFrame based on specific columns
lablelsdf.drop_duplicates(subset=['image_name','pred_class_number','bbox1','bbox2'],inplace=True)

# Return the resulting DataFrame after removing duplicate rows
lablelsdf
# Out:
#                                             image_name  pred_class_number
# 0    CabinCruiserUnder5Kn-3e7bd318-adea-4749-a5a8-4...                4.0  \
# 1    CabinCruiserUnder5Kn-3f9b2d89-7e29-49db-bcb7-5...                4.0
# 2    CabinCruiserUnder5Kn-42025ea3-5642-42d9-a8f6-5...                4.0
# 3    CabinCruiserUnder5Kn-464afd78-62c0-41f6-b76a-7...                4.0
# 4    CabinCruiserUnder5Kn-472b404c-cf3f-4cd4-86e3-3...                4.0
# ..                                                 ...                ...
# 405  CabinCruiserUnder5Kn-3881fe46-2a2a-4468-bd8d-6...                4.0
# 406  CabinCruiserUnder5Kn-3881fe46-2a2a-4468-bd8d-6...                4.0
# 407  CabinCruiserUnder5Kn-39835a77-59c4-4570-9381-2...                4.0
# 408  CabinCruiserUnder5Kn-39baf9ac-203d-4996-a506-8...                4.0
# 409  CabinCruiserUnder5Kn-3c3eaae5-e4af-4e54-aacc-0...                0.0
#
#     pred_class_name real_class_name  bbox1  bbox2  bbox3  bbox4
# 0              open    cabincruiser    0.1    0.3    0.2    0.2  \
# 1              open    cabincruiser    0.7    0.4    0.6    0.3
# 2              open    cabincruiser    0.6    0.6    0.8    0.5
# 3              open    cabincruiser    0.6    0.5    0.2    0.1
# 4              open    cabincruiser    0.7    0.4    0.6    0.4
# ..              ...             ...    ...    ...    ...    ...
# 405            open    cabincruiser    0.6    0.4    0.6    0.3
# 406            open    cabincruiser    0.6    0.6    0.3    0.3
# 407            open    cabincruiser    0.4    0.2    0.3    0.2
# 408            open    cabincruiser    0.4    0.4    0.4    0.2
# 409    cabincruiser    cabincruiser    0.7    0.4    0.5    0.4
#
#      confidence_score
# 0                 0.9
# 1                 0.8
# 2                 0.8
# 3                 0.9
# 4                 0.5
# ..                ...
# 405               0.8
# 406               0.9
# 407               0.9
# 408               0.9
# 409               0.9
#
# [410 rows x 9 columns]

# %%
# group the dataframe by 'image_name', and select the row with the highest 'confidence_score'
# for each group using the 'idxmax()' method
lablelsdf_filtered = lablelsdf.loc[lablelsdf.groupby('image_name')['confidence_score'].idxmax()].reset_index(drop=True)
lablelsdf_filtered.real_class_name[lablelsdf_filtered.real_class_name == 'halfcab'] = 'open'
# return the filtered dataframe
lablelsdf_filtered
# Out:
# C:\Users\LAPTOP WORLD\AppData\Local\Temp\ipykernel_11644\832828786.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lablelsdf_filtered.real_class_name[lablelsdf_filtered.real_class_name == 'halfcab'] = 'open'
#                                             image_name  pred_class_number
# 0    CabinCruiserOver5Kn-43bcd1e7-ab32-4723-bc95-d4...                4.0  \
# 1    CabinCruiserOver5Kn-7abeee81-5ec7-43cf-ac74-b8...                4.0
# 2    CabinCruiserOver5Kn-881e4b3a-6a54-4db0-b6df-0a...                4.0
# 3    CabinCruiserOver5Kn-8b589e36-2a1a-45ac-880e-d4...                4.0
# 4    CabinCruiserOver5Kn-9628196e-cd7c-49b2-aa93-e4...                4.0
# ..                                                 ...                ...
# 388  OpenUnder5kn-994e20ad-cf7e-47f9-bb24-d1cf59fdc...                4.0
# 389  OpenUnder5kn-aa8b06fe-5b08-4475-beae-396c48c85...                4.0
# 390  OpenUnder5kn-b0e278c0-a592-4c4d-bd98-77ca11e1e...                4.0
# 391  OpenUnder5kn-c5558165-441c-4ea8-ab91-7c60a9150...                4.0
# 392  OpenUnder5kn-e99aa0f7-9675-4359-9780-1d56ce724...                4.0
#
#     pred_class_name real_class_name  bbox1  bbox2  bbox3  bbox4
# 0              open    cabincruiser    0.1    0.8    0.3    0.5  \
# 1              open    cabincruiser    0.5    0.3    0.3    0.2
# 2              open    cabincruiser    0.5    0.3    0.6    0.4
# 3              open    cabincruiser    0.7    0.3    0.5    0.2
# 4              open    cabincruiser    0.8    0.2    0.4    0.3
# ..              ...             ...    ...    ...    ...    ...
# 388            open            open    0.5    0.5    0.6    0.3
# 389            open            open    0.3    0.3    0.5    0.2
# 390            open            open    0.4    0.5    0.6    0.3
# 391            open            open    0.3    0.6    0.7    0.3
# 392            open            open    0.3    0.4    0.6    0.3
#
#      confidence_score
# 0                 0.9
# 1                 0.9
# 2                 0.9
# 3                 0.9
# 4                 0.9
# ..                ...
# 388               0.6
# 389               0.9
# 390               0.9
# 391               0.9
# 392               0.9
#
# [393 rows x 9 columns]

# %%
lablelsdf_filtered.to_csv('ImageLabels.csv',index=False) # saving to a csv.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Calculate accuracy, precision, and recall scores
acc = accuracy_score(lablelsdf_filtered.real_class_name, lablelsdf_filtered.pred_class_name) # Calculates the accuracy score of the model
pre = precision_score(lablelsdf_filtered.real_class_name, lablelsdf_filtered.pred_class_name, average='macro') # Calculates the macro-averaged precision score of the model
rec = recall_score(lablelsdf_filtered.real_class_name, lablelsdf_filtered.pred_class_name, average='macro') # Calculates the macro-averaged recall score of the model

print(f"""
accuracy = {round(acc*100,2)}%
precision = {round(pre*100,2)}%
recall = {round(rec*100,2)}%
""")
# Out:
# accuracy = 65.14%
# precision = 60.36%
# recall = 50.94%
# c:\Users\LAPTOP WORLD\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

y_true, y_pred = lablelsdf_filtered.real_class_name, lablelsdf_filtered.pred_class_name

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))
ax.imshow(cm, cmap='RdYlGn')

# Add labels and ticks to the plot
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_xticks(np.arange(len(np.unique(y_true))))
ax.set_yticks(np.arange(len(np.unique(y_true))))
ax.set_xticklabels(np.unique(y_true))
ax.set_yticklabels(np.unique(y_true))
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Add text to the plot
for i in range(len(np.unique(y_true))):
    for j in range(len(np.unique(y_true))):
        ax.text(j, i, cm[i, j], ha="center", va="center", color="white")

# Display the plot
plt.show()

# %% [markdown]
# From this confusion matrix we can see that our model predicted all of the new data's cabincruisers and Humanpowereds as mostly halfcaps, it was good in predecting the Opens, I guess we need to look at our data and see if it's well labeled.

# %% [markdown]
# This code reads the images in the data/validation/images directory one by one, runs the YOLOv5 object detection model on each image using the detect.py script, and waits for 6 seconds before moving on to the next image. The last.pt file contains the pre-trained weights of the YOLOv5 model. The detected objects are saved in the runs/detect directory.

# %% [markdown]
# #### You'll find the predections in this path:
#
#  `yolov5\runs\detect\`

# %%
import matplotlib.pyplot as plt
import os

# Set initial counter to zero
n = 0
# Loop through directories in the detect folder
for d in os.listdir(r'yolov5\runs\detect'):
    # Loop through images in each directory
     for i in os.listdir(os.path.join(r'yolov5\runs\detect',d)):
     
          # Check if image is a jpeg and counter is less than 10
          if n < 10 and i.endswith('.jpg'):
               
               # Read image using matplotlib and display
               img = plt.imread(os.path.join(r'yolov5\runs\detect',d,i))
               plt.imshow(img)
               plt.show()
               
               # Increase counter
               n += 1
          
          # Break out of inner loop if counter is greater than or equal to 10
          else:
               break
